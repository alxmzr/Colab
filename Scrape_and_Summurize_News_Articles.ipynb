# %% [markdown]
# <a href="https://colab.research.google.com/github/alxmzr/Colab/blob/main/Scrape_and_Summurize_News_Articles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install nltk
#pip install newspaper3k

# %%
import nltk
from newspaper import Article

# %%
url = 'https://lifehacker.ru/sovety-ot-zabyvchivosti/'
article = Article(url)
article.download()
article.parse()
nltk.download('punkt')
article.nlp()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
article.authors
# Out:
# ['Елена Евстафьева', 'Лайфхакер И Издательство', 'Бомбора']

# %%
article.publish_date

# %%
article.top_image
# Out:
# 'https://cdn.lifehacker.ru/wp-content/uploads/2019/01/3-soveta-dlya-tex-kto-stal-slishkom-zabyvchiv_1548764671-1024x512.jpg'

# %%
print(article.text)
# Out:
# Эту статью можно послушать. Если вам так удобнее, включайте подкаст.
#
# Облегчите вспоминание информации
#
# Во-первых, старайтесь часто припоминать то, что хотите запомнить. Например, если вы каждый раз, видя чьё-то лицо, будете вспоминать имя этого человека, то в итоге потом оно будет сразу само собой всплывать у вас в памяти.
#
# Второй метод — это группировка информации. Есть такое явление, которое называется «магическое число семь». Суть его в том, что человек одновременно может запомнить ограниченное количество элементов информации, например, слов или чисел. Кто-то может запомнить 7, кто-то — только 3, в среднем это число составляет 5±2. Если элементов информации больше этого значения, то человек её забывает. Получается, объём данных, которые мы с лёгкостью можем запоминать, сильно ограничен.
#
# Но если сгруппировать информацию, то можно запомнить гораздо больше.
#
# ...

# %%
print(article.summary)
# Out:
# Например, если вы всегда встречаетесь с людьми в одном и том же кабинете, вам будет сложнее запомнить, кто есть кто среди них.
# Например, о том, что вы делали вместе, или что вы подарили ему и т. д.Чтобы легко извлекать из памяти информацию, крайне важно использовать какой-нибудь из этих приёмов.
# Нет ничего удивительного в том, что вы не можете вспомнить что-то, если вы не использовали ни один из этих методов.
# Поборите интернет-зависимостьЛюди с интернет-зависимостью часто жалуются на то, что они не то чтобы стали хуже всё запоминать, а скорее стали хуже вспоминать.
# Когда вы это сделаете, и вместо привычных действий вам придётся сразу браться за скучную работу, вы наверняка захотите всё вернуть обратно.
