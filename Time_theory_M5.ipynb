# %% [markdown]
# <a href="https://colab.research.google.com/github/alxmzr/Colab/blob/main/Time_theory_M5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas.tseries.offsets import Minute
import pandas as pd
from datetime import datetime
from google.colab import drive

drive.mount('/content/drive')

file_path = '/content/drive/My Drive/EURUSDM152023.csv'

column_names = ["date", "time", "open", "high", "low", "close", "volume"]

df = pd.read_csv(file_path, names=column_names)

df['datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'])

start_time = pd.to_datetime('6:00')
end_time = pd.to_datetime('20:00')
filtered_df = df[(df['datetime'].dt.time >= start_time.time()) & (df['datetime'].dt.time <= end_time.time())]

filtered_df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#              date   time     open     high      low    close  volume  \
# 0      2021.03.02  11:00  1.20022  1.20058  1.19915  1.20053    1424
# 1      2021.03.02  11:15  1.20053  1.20074  1.20006  1.20057    1139
# 2      2021.03.02  11:30  1.20058  1.20138  1.20038  1.20120    1159
# 3      2021.03.02  11:45  1.20119  1.20145  1.20061  1.20061    1193
# 4      2021.03.02  12:00  1.20062  1.20126  1.20060  1.20121    1181
# ...           ...    ...      ...      ...      ...      ...     ...
# 64980  2023.10.13  19:00  1.05008  1.05116  1.04994  1.05110     667
# 64981  2023.10.13  19:15  1.05110  1.05152  1.05093  1.05130     662
# 64982  2023.10.13  19:30  1.05129  1.05133  1.05094  1.05113     655
# 64983  2023.10.13  19:45  1.05113  1.05131  1.05068  1.05092     676
# 64984  2023.10.13  20:00  1.05092  1.05099  1.05011  1.05024     703
#
#                  datetime
# 0     2021-03-02 11:00:00
# 1     2021-03-02 11:15:00
# 2     2021-03-02 11:30:00
# 3     2021-03-02 11:45:00
# 4     2021-03-02 12:00:00
# ...                   ...
# 64980 2023-10-13 19:00:00
# 64981 2023-10-13 19:15:00
# 64982 2023-10-13 19:30:00
# 64983 2023-10-13 19:45:00
# 64984 2023-10-13 20:00:00
#
# [38654 rows x 8 columns]

# %%
# Assuming you have loaded and filtered your data as "filtered_df" as per the previous steps

# Group the data by date
grouped = filtered_df.groupby('date')

# Initialize dictionaries to store the results
max_high_times = {}
min_low_times = {}
max_high_counts = {}
min_low_counts = {}

# Iterate through each group (day)
for date, group in grouped:
    # Find the row with the highest "high" and lowest "low" for the day
    max_high_row = group[group['high'] == group['high'].max()]
    min_low_row = group[group['low'] == group['low'].min()]

    # Extract the times from the rows
    max_high_time = max_high_row['time'].iloc[0]
    min_low_time = min_low_row['time'].iloc[0]

    # Calculate how many times each event occurred for the day
    count_max_high = len(group[group['high'] == group['high'].max()])
    count_min_low = len(group[group['low'] == group['low'].min()])

    # Store the results in dictionaries
    max_high_times[date] = max_high_time
    min_low_times[date] = min_low_time
    max_high_counts[date] = count_max_high
    min_low_counts[date] = count_min_low

# Print the results
for date in grouped.groups.keys():
    print(f"On {date}, the highest 'high' price occurred at {max_high_times[date]} and repeated {max_high_counts[date]} times.")
    print(f"On {date}, the lowest 'low' price occurred at {min_low_times[date]} and repeated {min_low_counts[date]} times.")
# Out:
# On 2021.03.02, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.03.02, the lowest 'low' price occurred at 11:00 and repeated 1 times.
# On 2021.03.03, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2021.03.03, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2021.03.04, the highest 'high' price occurred at 09:00 and repeated 1 times.
# On 2021.03.04, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.03.05, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.03.05, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.03.08, the highest 'high' price occurred at 08:00 and repeated 1 times.
# On 2021.03.08, the lowest 'low' price occurred at 18:45 and repeated 1 times.
# On 2021.03.09, the highest 'high' price occurred at 13:30 and repeated 1 times.
# On 2021.03.09, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2021.03.10, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2021.03.10, the lowest 'low' price occurred at 08:00 and repeated 1 times.
# On 2021.03.11, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.03.11, the lowest 'low' price occurred at 08:00 and repeated 1 times.
# On 2021.03.12, the highest 'high' price occurred at 06:15 and repeated 2 times.
# On 2021.03.12, the lowest 'low' price occurred at 12:00 and repeated 1 times.
# On 2021.03.15, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.03.15, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2021.03.16, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2021.03.16, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2021.03.17, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.03.17, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2021.03.18, the highest 'high' price occurred at 09:00 and repeated 1 times.
# On 2021.03.18, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2021.03.19, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2021.03.19, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.03.22, the highest 'high' price occurred at 19:30 and repeated 2 times.
# On 2021.03.22, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2021.03.23, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.03.23, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.03.24, the highest 'high' price occurred at 06:00 and repeated 2 times.
# On 2021.03.24, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2021.03.25, the highest 'high' price occurred at 07:30 and repeated 1 times.
# On 2021.03.25, the lowest 'low' price occurred at 19:00 and repeated 1 times.
# On 2021.03.26, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.03.26, the lowest 'low' price occurred at 13:30 and repeated 1 times.
# On 2021.03.29, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2021.03.29, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2021.03.30, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2021.03.30, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2021.03.31, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.03.31, the lowest 'low' price occurred at 07:15 and repeated 1 times.
# On 2021.04.01, the highest 'high' price occurred at 19:15 and repeated 1 times.
# On 2021.04.01, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2021.04.02, the highest 'high' price occurred at 11:45 and repeated 1 times.
# On 2021.04.02, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.04.05, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2021.04.05, the lowest 'low' price occurred at 13:00 and repeated 1 times.
# On 2021.04.06, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.04.06, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2021.04.07, the highest 'high' price occurred at 17:30 and repeated 1 times.
# On 2021.04.07, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2021.04.08, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2021.04.08, the lowest 'low' price occurred at 13:45 and repeated 2 times.
# On 2021.04.09, the highest 'high' price occurred at 06:45 and repeated 1 times.
# On 2021.04.09, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2021.04.12, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2021.04.12, the lowest 'low' price occurred at 11:00 and repeated 1 times.
# On 2021.04.13, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.04.13, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.04.14, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2021.04.14, the lowest 'low' price occurred at 14:00 and repeated 1 times.
# On 2021.04.15, the highest 'high' price occurred at 12:15 and repeated 1 times.
# On 2021.04.15, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.04.16, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2021.04.16, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.04.19, the highest 'high' price occurred at 14:00 and repeated 1 times.
# On 2021.04.19, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.04.20, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2021.04.20, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2021.04.21, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2021.04.21, the lowest 'low' price occurred at 13:15 and repeated 1 times.
# On 2021.04.22, the highest 'high' price occurred at 16:00 and repeated 1 times.
# On 2021.04.22, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.04.23, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.04.23, the lowest 'low' price occurred at 06:45 and repeated 1 times.
# On 2021.04.26, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2021.04.26, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2021.04.27, the highest 'high' price occurred at 14:45 and repeated 1 times.
# On 2021.04.27, the lowest 'low' price occurred at 12:00 and repeated 1 times.
# On 2021.04.28, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2021.04.28, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2021.04.29, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.04.29, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2021.04.30, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.04.30, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.05.03, the highest 'high' price occurred at 18:00 and repeated 1 times.
# On 2021.05.03, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2021.05.04, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.05.04, the lowest 'low' price occurred at 12:00 and repeated 1 times.
# On 2021.05.05, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2021.05.05, the lowest 'low' price occurred at 10:30 and repeated 1 times.
# On 2021.05.06, the highest 'high' price occurred at 16:45 and repeated 1 times.
# On 2021.05.06, the lowest 'low' price occurred at 06:30 and repeated 1 times.
# On 2021.05.07, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2021.05.07, the lowest 'low' price occurred at 09:15 and repeated 2 times.
# On 2021.05.10, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2021.05.10, the lowest 'low' price occurred at 10:30 and repeated 1 times.
# On 2021.05.11, the highest 'high' price occurred at 16:00 and repeated 1 times.
# On 2021.05.11, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2021.05.12, the highest 'high' price occurred at 16:00 and repeated 1 times.
# On 2021.05.12, the lowest 'low' price occurred at 19:45 and repeated 2 times.
# On 2021.05.13, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2021.05.13, the lowest 'low' price occurred at 11:45 and repeated 1 times.
# On 2021.05.14, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2021.05.14, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.05.17, the highest 'high' price occurred at 13:45 and repeated 2 times.
# On 2021.05.17, the lowest 'low' price occurred at 08:45 and repeated 1 times.
# On 2021.05.18, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2021.05.18, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.05.19, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2021.05.19, the lowest 'low' price occurred at 14:15 and repeated 1 times.
# On 2021.05.20, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2021.05.20, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.05.21, the highest 'high' price occurred at 09:00 and repeated 1 times.
# On 2021.05.21, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2021.05.24, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2021.05.24, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2021.05.25, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2021.05.25, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2021.05.26, the highest 'high' price occurred at 08:15 and repeated 1 times.
# On 2021.05.26, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.05.27, the highest 'high' price occurred at 11:15 and repeated 1 times.
# On 2021.05.27, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2021.05.28, the highest 'high' price occurred at 19:30 and repeated 2 times.
# On 2021.05.28, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.05.31, the highest 'high' price occurred at 18:00 and repeated 1 times.
# On 2021.05.31, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2021.06.01, the highest 'high' price occurred at 17:30 and repeated 1 times.
# On 2021.06.01, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2021.06.02, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.06.02, the lowest 'low' price occurred at 14:30 and repeated 1 times.
# On 2021.06.03, the highest 'high' price occurred at 13:00 and repeated 1 times.
# On 2021.06.03, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2021.06.04, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2021.06.04, the lowest 'low' price occurred at 09:15 and repeated 2 times.
# On 2021.06.07, the highest 'high' price occurred at 19:00 and repeated 1 times.
# On 2021.06.07, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2021.06.08, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.06.08, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2021.06.09, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2021.06.09, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2021.06.10, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2021.06.10, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2021.06.11, the highest 'high' price occurred at 09:15 and repeated 1 times.
# On 2021.06.11, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.06.14, the highest 'high' price occurred at 16:15 and repeated 3 times.
# On 2021.06.14, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2021.06.15, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2021.06.15, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2021.06.16, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2021.06.16, the lowest 'low' price occurred at 18:30 and repeated 2 times.
# On 2021.06.17, the highest 'high' price occurred at 08:45 and repeated 1 times.
# On 2021.06.17, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2021.06.18, the highest 'high' price occurred at 06:30 and repeated 1 times.
# On 2021.06.18, the lowest 'low' price occurred at 18:15 and repeated 1 times.
# On 2021.06.21, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2021.06.21, the lowest 'low' price occurred at 06:45 and repeated 1 times.
# On 2021.06.22, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2021.06.22, the lowest 'low' price occurred at 12:45 and repeated 1 times.
# On 2021.06.23, the highest 'high' price occurred at 16:45 and repeated 1 times.
# On 2021.06.23, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2021.06.24, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2021.06.24, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2021.06.25, the highest 'high' price occurred at 16:45 and repeated 1 times.
# On 2021.06.25, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2021.06.28, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2021.06.28, the lowest 'low' price occurred at 15:00 and repeated 1 times.
# On 2021.06.29, the highest 'high' price occurred at 09:15 and repeated 1 times.
# On 2021.06.29, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.06.30, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2021.06.30, the lowest 'low' price occurred at 18:45 and repeated 1 times.
# On 2021.07.01, the highest 'high' price occurred at 15:00 and repeated 2 times.
# On 2021.07.01, the lowest 'low' price occurred at 09:30 and repeated 1 times.
# On 2021.07.02, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2021.07.02, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.07.05, the highest 'high' price occurred at 14:00 and repeated 1 times.
# On 2021.07.05, the lowest 'low' price occurred at 07:00 and repeated 1 times.
# On 2021.07.06, the highest 'high' price occurred at 09:00 and repeated 1 times.
# On 2021.07.06, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2021.07.07, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2021.07.07, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2021.07.08, the highest 'high' price occurred at 17:30 and repeated 1 times.
# On 2021.07.08, the lowest 'low' price occurred at 06:00 and repeated 2 times.
# On 2021.07.09, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.07.09, the lowest 'low' price occurred at 09:30 and repeated 1 times.
# On 2021.07.12, the highest 'high' price occurred at 11:15 and repeated 1 times.
# On 2021.07.12, the lowest 'low' price occurred at 14:45 and repeated 1 times.
# On 2021.07.13, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2021.07.13, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2021.07.14, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.07.14, the lowest 'low' price occurred at 12:00 and repeated 1 times.
# On 2021.07.15, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2021.07.15, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.07.16, the highest 'high' price occurred at 12:45 and repeated 1 times.
# On 2021.07.16, the lowest 'low' price occurred at 14:45 and repeated 1 times.
# On 2021.07.19, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2021.07.19, the lowest 'low' price occurred at 15:15 and repeated 1 times.
# On 2021.07.20, the highest 'high' price occurred at 12:45 and repeated 1 times.
# On 2021.07.20, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2021.07.21, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2021.07.21, the lowest 'low' price occurred at 10:30 and repeated 1 times.
# On 2021.07.22, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2021.07.22, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2021.07.23, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2021.07.23, the lowest 'low' price occurred at 14:30 and repeated 1 times.
# On 2021.07.26, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2021.07.26, the lowest 'low' price occurred at 11:15 and repeated 1 times.
# On 2021.07.27, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2021.07.27, the lowest 'low' price occurred at 11:15 and repeated 1 times.
# On 2021.07.28, the highest 'high' price occurred at 11:45 and repeated 1 times.
# On 2021.07.28, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2021.07.29, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2021.07.29, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2021.07.30, the highest 'high' price occurred at 12:30 and repeated 1 times.
# On 2021.07.30, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2021.08.02, the highest 'high' price occurred at 13:00 and repeated 1 times.
# On 2021.08.02, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2021.08.03, the highest 'high' price occurred at 14:45 and repeated 1 times.
# On 2021.08.03, the lowest 'low' price occurred at 18:15 and repeated 1 times.
# On 2021.08.04, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2021.08.04, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2021.08.05, the highest 'high' price occurred at 15:00 and repeated 1 times.
# On 2021.08.05, the lowest 'low' price occurred at 12:45 and repeated 1 times.
# On 2021.08.06, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2021.08.06, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2021.08.09, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2021.08.09, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2021.08.10, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2021.08.10, the lowest 'low' price occurred at 17:15 and repeated 1 times.
# On 2021.08.11, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.08.11, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2021.08.12, the highest 'high' price occurred at 11:45 and repeated 1 times.
# On 2021.08.12, the lowest 'low' price occurred at 16:45 and repeated 2 times.
# On 2021.08.13, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2021.08.13, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2021.08.16, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.08.16, the lowest 'low' price occurred at 14:45 and repeated 1 times.
# On 2021.08.17, the highest 'high' price occurred at 11:15 and repeated 1 times.
# On 2021.08.17, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.08.18, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2021.08.18, the lowest 'low' price occurred at 18:15 and repeated 1 times.
# On 2021.08.19, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2021.08.19, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.08.20, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2021.08.20, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.08.23, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2021.08.23, the lowest 'low' price occurred at 10:30 and repeated 1 times.
# On 2021.08.24, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.08.24, the lowest 'low' price occurred at 11:45 and repeated 1 times.
# On 2021.08.25, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2021.08.25, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.08.26, the highest 'high' price occurred at 14:15 and repeated 1 times.
# On 2021.08.26, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2021.08.27, the highest 'high' price occurred at 17:30 and repeated 1 times.
# On 2021.08.27, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2021.08.30, the highest 'high' price occurred at 06:30 and repeated 1 times.
# On 2021.08.30, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.08.31, the highest 'high' price occurred at 14:15 and repeated 1 times.
# On 2021.08.31, the lowest 'low' price occurred at 18:30 and repeated 1 times.
# On 2021.09.01, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.09.01, the lowest 'low' price occurred at 09:15 and repeated 1 times.
# On 2021.09.02, the highest 'high' price occurred at 18:00 and repeated 1 times.
# On 2021.09.02, the lowest 'low' price occurred at 08:00 and repeated 1 times.
# On 2021.09.03, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2021.09.03, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.09.06, the highest 'high' price occurred at 09:15 and repeated 1 times.
# On 2021.09.06, the lowest 'low' price occurred at 12:15 and repeated 1 times.
# On 2021.09.07, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.09.07, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2021.09.08, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.09.08, the lowest 'low' price occurred at 17:30 and repeated 2 times.
# On 2021.09.09, the highest 'high' price occurred at 14:45 and repeated 2 times.
# On 2021.09.09, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2021.09.10, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2021.09.10, the lowest 'low' price occurred at 19:00 and repeated 1 times.
# On 2021.09.13, the highest 'high' price occurred at 18:30 and repeated 1 times.
# On 2021.09.13, the lowest 'low' price occurred at 14:45 and repeated 1 times.
# On 2021.09.14, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2021.09.14, the lowest 'low' price occurred at 14:00 and repeated 1 times.
# On 2021.09.15, the highest 'high' price occurred at 13:45 and repeated 2 times.
# On 2021.09.15, the lowest 'low' price occurred at 09:30 and repeated 1 times.
# On 2021.09.16, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.09.16, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2021.09.17, the highest 'high' price occurred at 15:00 and repeated 1 times.
# On 2021.09.17, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.09.20, the highest 'high' price occurred at 18:00 and repeated 3 times.
# On 2021.09.20, the lowest 'low' price occurred at 12:30 and repeated 2 times.
# On 2021.09.21, the highest 'high' price occurred at 15:00 and repeated 1 times.
# On 2021.09.21, the lowest 'low' price occurred at 18:30 and repeated 1 times.
# On 2021.09.22, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2021.09.22, the lowest 'low' price occurred at 07:00 and repeated 1 times.
# On 2021.09.23, the highest 'high' price occurred at 18:00 and repeated 1 times.
# On 2021.09.23, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.09.24, the highest 'high' price occurred at 06:30 and repeated 1 times.
# On 2021.09.24, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.09.27, the highest 'high' price occurred at 07:15 and repeated 1 times.
# On 2021.09.27, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2021.09.28, the highest 'high' price occurred at 08:00 and repeated 1 times.
# On 2021.09.28, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2021.09.29, the highest 'high' price occurred at 08:30 and repeated 2 times.
# On 2021.09.29, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2021.09.30, the highest 'high' price occurred at 11:00 and repeated 1 times.
# On 2021.09.30, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2021.10.01, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2021.10.01, the lowest 'low' price occurred at 13:00 and repeated 1 times.
# On 2021.10.04, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2021.10.04, the lowest 'low' price occurred at 06:45 and repeated 1 times.
# On 2021.10.05, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2021.10.05, the lowest 'low' price occurred at 17:15 and repeated 1 times.
# On 2021.10.06, the highest 'high' price occurred at 06:00 and repeated 2 times.
# On 2021.10.06, the lowest 'low' price occurred at 13:15 and repeated 1 times.
# On 2021.10.07, the highest 'high' price occurred at 14:30 and repeated 1 times.
# On 2021.10.07, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2021.10.08, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2021.10.08, the lowest 'low' price occurred at 08:45 and repeated 1 times.
# On 2021.10.11, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2021.10.11, the lowest 'low' price occurred at 12:45 and repeated 1 times.
# On 2021.10.12, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2021.10.12, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.10.13, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.10.13, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.10.14, the highest 'high' price occurred at 12:15 and repeated 1 times.
# On 2021.10.14, the lowest 'low' price occurred at 18:30 and repeated 1 times.
# On 2021.10.15, the highest 'high' price occurred at 11:00 and repeated 1 times.
# On 2021.10.15, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.10.18, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.10.18, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2021.10.19, the highest 'high' price occurred at 12:45 and repeated 1 times.
# On 2021.10.19, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2021.10.20, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.10.20, the lowest 'low' price occurred at 10:30 and repeated 1 times.
# On 2021.10.21, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2021.10.21, the lowest 'low' price occurred at 15:00 and repeated 1 times.
# On 2021.10.22, the highest 'high' price occurred at 18:00 and repeated 1 times.
# On 2021.10.22, the lowest 'low' price occurred at 19:00 and repeated 1 times.
# On 2021.10.25, the highest 'high' price occurred at 07:00 and repeated 1 times.
# On 2021.10.25, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2021.10.26, the highest 'high' price occurred at 14:00 and repeated 1 times.
# On 2021.10.26, the lowest 'low' price occurred at 18:30 and repeated 1 times.
# On 2021.10.27, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2021.10.27, the lowest 'low' price occurred at 12:30 and repeated 1 times.
# On 2021.10.28, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2021.10.28, the lowest 'low' price occurred at 12:30 and repeated 1 times.
# On 2021.10.29, the highest 'high' price occurred at 06:45 and repeated 1 times.
# On 2021.10.29, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2021.11.01, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.11.01, the lowest 'low' price occurred at 06:30 and repeated 1 times.
# On 2021.11.02, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2021.11.02, the lowest 'low' price occurred at 18:30 and repeated 1 times.
# On 2021.11.03, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.11.03, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.11.04, the highest 'high' price occurred at 06:00 and repeated 2 times.
# On 2021.11.04, the lowest 'low' price occurred at 17:15 and repeated 2 times.
# On 2021.11.05, the highest 'high' price occurred at 19:00 and repeated 1 times.
# On 2021.11.05, the lowest 'low' price occurred at 15:00 and repeated 1 times.
# On 2021.11.08, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2021.11.08, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2021.11.09, the highest 'high' price occurred at 16:45 and repeated 1 times.
# On 2021.11.09, the lowest 'low' price occurred at 15:00 and repeated 1 times.
# On 2021.11.10, the highest 'high' price occurred at 07:00 and repeated 1 times.
# On 2021.11.10, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.11.11, the highest 'high' price occurred at 08:30 and repeated 1 times.
# On 2021.11.11, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.11.12, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2021.11.12, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2021.11.15, the highest 'high' price occurred at 07:45 and repeated 1 times.
# On 2021.11.15, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2021.11.16, the highest 'high' price occurred at 07:00 and repeated 1 times.
# On 2021.11.16, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2021.11.17, the highest 'high' price occurred at 14:15 and repeated 1 times.
# On 2021.11.17, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2021.11.18, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2021.11.18, the lowest 'low' price occurred at 08:30 and repeated 1 times.
# On 2021.11.19, the highest 'high' price occurred at 08:45 and repeated 1 times.
# On 2021.11.19, the lowest 'low' price occurred at 15:00 and repeated 1 times.
# On 2021.11.22, the highest 'high' price occurred at 12:30 and repeated 1 times.
# On 2021.11.22, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2021.11.23, the highest 'high' price occurred at 11:00 and repeated 1 times.
# On 2021.11.23, the lowest 'low' price occurred at 07:45 and repeated 1 times.
# On 2021.11.24, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2021.11.24, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.11.25, the highest 'high' price occurred at 14:30 and repeated 1 times.
# On 2021.11.25, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2021.11.26, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.11.26, the lowest 'low' price occurred at 06:15 and repeated 1 times.
# On 2021.11.29, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2021.11.29, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2021.11.30, the highest 'high' price occurred at 16:45 and repeated 2 times.
# On 2021.11.30, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2021.12.01, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2021.12.01, the lowest 'low' price occurred at 10:45 and repeated 1 times.
# On 2021.12.02, the highest 'high' price occurred at 14:45 and repeated 1 times.
# On 2021.12.02, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.12.03, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2021.12.03, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2021.12.06, the highest 'high' price occurred at 12:15 and repeated 1 times.
# On 2021.12.06, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2021.12.07, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2021.12.07, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2021.12.08, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2021.12.08, the lowest 'low' price occurred at 14:15 and repeated 1 times.
# On 2021.12.09, the highest 'high' price occurred at 06:45 and repeated 1 times.
# On 2021.12.09, the lowest 'low' price occurred at 18:15 and repeated 1 times.
# On 2021.12.10, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2021.12.10, the lowest 'low' price occurred at 12:45 and repeated 1 times.
# On 2021.12.13, the highest 'high' price occurred at 19:15 and repeated 1 times.
# On 2021.12.13, the lowest 'low' price occurred at 11:15 and repeated 1 times.
# On 2021.12.14, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2021.12.14, the lowest 'low' price occurred at 18:45 and repeated 1 times.
# On 2021.12.15, the highest 'high' price occurred at 11:15 and repeated 1 times.
# On 2021.12.15, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2021.12.16, the highest 'high' price occurred at 16:00 and repeated 1 times.
# On 2021.12.16, the lowest 'low' price occurred at 08:00 and repeated 1 times.
# On 2021.12.17, the highest 'high' price occurred at 07:45 and repeated 1 times.
# On 2021.12.17, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2021.12.20, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2021.12.20, the lowest 'low' price occurred at 06:15 and repeated 1 times.
# On 2021.12.21, the highest 'high' price occurred at 11:00 and repeated 1 times.
# On 2021.12.21, the lowest 'low' price occurred at 18:45 and repeated 1 times.
# On 2021.12.22, the highest 'high' price occurred at 18:00 and repeated 1 times.
# On 2021.12.22, the lowest 'low' price occurred at 09:30 and repeated 1 times.
# On 2021.12.23, the highest 'high' price occurred at 07:15 and repeated 1 times.
# On 2021.12.23, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.12.24, the highest 'high' price occurred at 12:00 and repeated 1 times.
# On 2021.12.24, the lowest 'low' price occurred at 17:45 and repeated 2 times.
# On 2021.12.27, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2021.12.27, the lowest 'low' price occurred at 11:00 and repeated 1 times.
# On 2021.12.28, the highest 'high' price occurred at 13:30 and repeated 1 times.
# On 2021.12.28, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2021.12.29, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2021.12.29, the lowest 'low' price occurred at 11:15 and repeated 1 times.
# On 2021.12.30, the highest 'high' price occurred at 14:45 and repeated 1 times.
# On 2021.12.30, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2021.12.31, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2021.12.31, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2022.01.03, the highest 'high' price occurred at 13:15 and repeated 1 times.
# On 2022.01.03, the lowest 'low' price occurred at 19:15 and repeated 2 times.
# On 2022.01.04, the highest 'high' price occurred at 17:30 and repeated 1 times.
# On 2022.01.04, the lowest 'low' price occurred at 14:15 and repeated 1 times.
# On 2022.01.05, the highest 'high' price occurred at 19:15 and repeated 1 times.
# On 2022.01.05, the lowest 'low' price occurred at 07:15 and repeated 1 times.
# On 2022.01.06, the highest 'high' price occurred at 16:45 and repeated 1 times.
# On 2022.01.06, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2022.01.07, the highest 'high' price occurred at 19:15 and repeated 1 times.
# On 2022.01.07, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2022.01.10, the highest 'high' price occurred at 11:15 and repeated 1 times.
# On 2022.01.10, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2022.01.11, the highest 'high' price occurred at 18:30 and repeated 1 times.
# On 2022.01.11, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2022.01.12, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2022.01.12, the lowest 'low' price occurred at 12:45 and repeated 1 times.
# On 2022.01.13, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2022.01.13, the lowest 'low' price occurred at 08:45 and repeated 1 times.
# On 2022.01.14, the highest 'high' price occurred at 07:30 and repeated 1 times.
# On 2022.01.14, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2022.01.17, the highest 'high' price occurred at 10:30 and repeated 1 times.
# On 2022.01.17, the lowest 'low' price occurred at 15:15 and repeated 1 times.
# On 2022.01.18, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2022.01.18, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2022.01.19, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2022.01.19, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.01.20, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2022.01.20, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2022.01.21, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2022.01.21, the lowest 'low' price occurred at 07:00 and repeated 1 times.
# On 2022.01.24, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2022.01.24, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2022.01.25, the highest 'high' price occurred at 06:15 and repeated 2 times.
# On 2022.01.25, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2022.01.26, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2022.01.26, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2022.01.27, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2022.01.27, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2022.01.28, the highest 'high' price occurred at 16:00 and repeated 1 times.
# On 2022.01.28, the lowest 'low' price occurred at 10:30 and repeated 1 times.
# On 2022.01.31, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2022.01.31, the lowest 'low' price occurred at 14:15 and repeated 1 times.
# On 2022.02.01, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2022.02.01, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.02.02, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2022.02.02, the lowest 'low' price occurred at 08:30 and repeated 1 times.
# On 2022.02.03, the highest 'high' price occurred at 18:30 and repeated 1 times.
# On 2022.02.03, the lowest 'low' price occurred at 14:45 and repeated 1 times.
# On 2022.02.04, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2022.02.04, the lowest 'low' price occurred at 17:15 and repeated 1 times.
# On 2022.02.07, the highest 'high' price occurred at 14:45 and repeated 1 times.
# On 2022.02.07, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2022.02.08, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2022.02.08, the lowest 'low' price occurred at 09:30 and repeated 1 times.
# On 2022.02.09, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2022.02.09, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2022.02.10, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2022.02.10, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2022.02.11, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2022.02.11, the lowest 'low' price occurred at 08:45 and repeated 1 times.
# On 2022.02.14, the highest 'high' price occurred at 07:45 and repeated 1 times.
# On 2022.02.14, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2022.02.15, the highest 'high' price occurred at 18:00 and repeated 1 times.
# On 2022.02.15, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2022.02.16, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2022.02.16, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.02.17, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2022.02.17, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.02.18, the highest 'high' price occurred at 10:45 and repeated 2 times.
# On 2022.02.18, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2022.02.21, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2022.02.21, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2022.02.22, the highest 'high' price occurred at 12:45 and repeated 1 times.
# On 2022.02.22, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.02.23, the highest 'high' price occurred at 11:45 and repeated 1 times.
# On 2022.02.23, the lowest 'low' price occurred at 18:15 and repeated 1 times.
# On 2022.02.24, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2022.02.24, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2022.02.25, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2022.02.25, the lowest 'low' price occurred at 12:30 and repeated 1 times.
# On 2022.02.28, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2022.02.28, the lowest 'low' price occurred at 06:45 and repeated 1 times.
# On 2022.03.01, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2022.03.01, the lowest 'low' price occurred at 19:00 and repeated 1 times.
# On 2022.03.02, the highest 'high' price occurred at 18:30 and repeated 1 times.
# On 2022.03.02, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2022.03.03, the highest 'high' price occurred at 08:45 and repeated 1 times.
# On 2022.03.03, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2022.03.04, the highest 'high' price occurred at 07:15 and repeated 1 times.
# On 2022.03.04, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2022.03.07, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2022.03.07, the lowest 'low' price occurred at 12:30 and repeated 1 times.
# On 2022.03.08, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2022.03.08, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2022.03.09, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2022.03.09, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.03.10, the highest 'high' price occurred at 14:45 and repeated 1 times.
# On 2022.03.10, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2022.03.11, the highest 'high' price occurred at 13:15 and repeated 1 times.
# On 2022.03.11, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2022.03.14, the highest 'high' price occurred at 18:30 and repeated 1 times.
# On 2022.03.14, the lowest 'low' price occurred at 06:15 and repeated 1 times.
# On 2022.03.15, the highest 'high' price occurred at 09:15 and repeated 1 times.
# On 2022.03.15, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2022.03.16, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2022.03.16, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2022.03.17, the highest 'high' price occurred at 19:00 and repeated 1 times.
# On 2022.03.17, the lowest 'low' price occurred at 08:15 and repeated 1 times.
# On 2022.03.18, the highest 'high' price occurred at 08:30 and repeated 1 times.
# On 2022.03.18, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2022.03.21, the highest 'high' price occurred at 11:00 and repeated 1 times.
# On 2022.03.21, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2022.03.22, the highest 'high' price occurred at 16:00 and repeated 1 times.
# On 2022.03.22, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2022.03.23, the highest 'high' price occurred at 07:45 and repeated 2 times.
# On 2022.03.23, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2022.03.24, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2022.03.24, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2022.03.25, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2022.03.25, the lowest 'low' price occurred at 18:45 and repeated 1 times.
# On 2022.03.28, the highest 'high' price occurred at 11:45 and repeated 1 times.
# On 2022.03.28, the lowest 'low' price occurred at 11:00 and repeated 1 times.
# On 2022.03.29, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2022.03.29, the lowest 'low' price occurred at 12:00 and repeated 1 times.
# On 2022.03.30, the highest 'high' price occurred at 17:45 and repeated 1 times.
# On 2022.03.30, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2022.03.31, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2022.03.31, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2022.04.01, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2022.04.01, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2022.04.04, the highest 'high' price occurred at 09:00 and repeated 1 times.
# On 2022.04.04, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2022.04.05, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2022.04.05, the lowest 'low' price occurred at 19:45 and repeated 2 times.
# On 2022.04.06, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2022.04.06, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2022.04.07, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2022.04.07, the lowest 'low' price occurred at 12:15 and repeated 1 times.
# On 2022.04.08, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2022.04.08, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2022.04.11, the highest 'high' price occurred at 13:15 and repeated 1 times.
# On 2022.04.11, the lowest 'low' price occurred at 19:00 and repeated 1 times.
# On 2022.04.12, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2022.04.12, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2022.04.13, the highest 'high' price occurred at 19:15 and repeated 1 times.
# On 2022.04.13, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2022.04.14, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2022.04.14, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2022.04.15, the highest 'high' price occurred at 11:45 and repeated 1 times.
# On 2022.04.15, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.04.18, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2022.04.18, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2022.04.19, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2022.04.19, the lowest 'low' price occurred at 08:15 and repeated 1 times.
# On 2022.04.20, the highest 'high' price occurred at 12:30 and repeated 1 times.
# On 2022.04.20, the lowest 'low' price occurred at 11:00 and repeated 1 times.
# On 2022.04.21, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2022.04.21, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2022.04.22, the highest 'high' price occurred at 09:00 and repeated 1 times.
# On 2022.04.22, the lowest 'low' price occurred at 18:15 and repeated 1 times.
# On 2022.04.25, the highest 'high' price occurred at 06:30 and repeated 1 times.
# On 2022.04.25, the lowest 'low' price occurred at 19:00 and repeated 1 times.
# On 2022.04.26, the highest 'high' price occurred at 06:30 and repeated 1 times.
# On 2022.04.26, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2022.04.27, the highest 'high' price occurred at 08:30 and repeated 2 times.
# On 2022.04.27, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2022.04.28, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2022.04.28, the lowest 'low' price occurred at 15:15 and repeated 1 times.
# On 2022.04.29, the highest 'high' price occurred at 11:30 and repeated 1 times.
# ...
# On 2023.05.19, the highest 'high' price occurred at 18:15 and repeated 1 times.
# On 2023.05.19, the lowest 'low' price occurred at 07:30 and repeated 1 times.
# On 2023.05.22, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2023.05.22, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2023.05.23, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2023.05.23, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2023.05.24, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2023.05.24, the lowest 'low' price occurred at 13:15 and repeated 1 times.
# On 2023.05.25, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2023.05.25, the lowest 'low' price occurred at 16:30 and repeated 1 times.
# On 2023.05.26, the highest 'high' price occurred at 14:30 and repeated 1 times.
# On 2023.05.26, the lowest 'low' price occurred at 18:15 and repeated 1 times.
# On 2023.05.29, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2023.05.29, the lowest 'low' price occurred at 17:15 and repeated 2 times.
# On 2023.05.30, the highest 'high' price occurred at 15:00 and repeated 1 times.
# On 2023.05.30, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2023.05.31, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2023.05.31, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2023.06.01, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2023.06.01, the lowest 'low' price occurred at 10:30 and repeated 1 times.
# On 2023.06.02, the highest 'high' price occurred at 09:00 and repeated 1 times.
# On 2023.06.02, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2023.06.05, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2023.06.05, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.06.06, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2023.06.06, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.06.07, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2023.06.07, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2023.06.08, the highest 'high' price occurred at 19:15 and repeated 1 times.
# On 2023.06.08, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2023.06.09, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2023.06.09, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2023.06.12, the highest 'high' price occurred at 12:30 and repeated 1 times.
# On 2023.06.12, the lowest 'low' price occurred at 06:15 and repeated 1 times.
# On 2023.06.13, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2023.06.13, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2023.06.14, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2023.06.14, the lowest 'low' price occurred at 08:45 and repeated 1 times.
# On 2023.06.15, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2023.06.15, the lowest 'low' price occurred at 09:45 and repeated 1 times.
# On 2023.06.16, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2023.06.16, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2023.06.19, the highest 'high' price occurred at 08:45 and repeated 1 times.
# On 2023.06.19, the lowest 'low' price occurred at 13:00 and repeated 1 times.
# On 2023.06.20, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2023.06.20, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2023.06.21, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2023.06.21, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2023.06.22, the highest 'high' price occurred at 14:00 and repeated 1 times.
# On 2023.06.22, the lowest 'low' price occurred at 19:00 and repeated 1 times.
# On 2023.06.23, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2023.06.23, the lowest 'low' price occurred at 12:00 and repeated 1 times.
# On 2023.06.26, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2023.06.26, the lowest 'low' price occurred at 11:00 and repeated 1 times.
# On 2023.06.27, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2023.06.27, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2023.06.28, the highest 'high' price occurred at 13:30 and repeated 1 times.
# On 2023.06.28, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2023.06.29, the highest 'high' price occurred at 15:00 and repeated 1 times.
# On 2023.06.29, the lowest 'low' price occurred at 16:30 and repeated 2 times.
# On 2023.06.30, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2023.06.30, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2023.07.03, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2023.07.03, the lowest 'low' price occurred at 10:45 and repeated 1 times.
# On 2023.07.04, the highest 'high' price occurred at 09:45 and repeated 2 times.
# On 2023.07.04, the lowest 'low' price occurred at 14:15 and repeated 1 times.
# On 2023.07.05, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2023.07.05, the lowest 'low' price occurred at 19:45 and repeated 2 times.
# On 2023.07.06, the highest 'high' price occurred at 15:00 and repeated 1 times.
# On 2023.07.06, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2023.07.07, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2023.07.07, the lowest 'low' price occurred at 11:15 and repeated 1 times.
# On 2023.07.10, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2023.07.10, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.07.11, the highest 'high' price occurred at 09:15 and repeated 1 times.
# On 2023.07.11, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.07.12, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2023.07.12, the lowest 'low' price occurred at 14:45 and repeated 1 times.
# On 2023.07.13, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2023.07.13, the lowest 'low' price occurred at 08:45 and repeated 1 times.
# On 2023.07.14, the highest 'high' price occurred at 12:00 and repeated 1 times.
# On 2023.07.14, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2023.07.17, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2023.07.17, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2023.07.18, the highest 'high' price occurred at 10:30 and repeated 1 times.
# On 2023.07.18, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2023.07.19, the highest 'high' price occurred at 12:30 and repeated 1 times.
# On 2023.07.19, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2023.07.20, the highest 'high' price occurred at 06:15 and repeated 1 times.
# On 2023.07.20, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2023.07.21, the highest 'high' price occurred at 09:15 and repeated 2 times.
# On 2023.07.21, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2023.07.24, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2023.07.24, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2023.07.25, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2023.07.25, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2023.07.26, the highest 'high' price occurred at 13:45 and repeated 1 times.
# On 2023.07.26, the lowest 'low' price occurred at 06:15 and repeated 1 times.
# On 2023.07.27, the highest 'high' price occurred at 13:15 and repeated 1 times.
# On 2023.07.27, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2023.07.28, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2023.07.28, the lowest 'low' price occurred at 10:45 and repeated 1 times.
# On 2023.07.31, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2023.07.31, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2023.08.01, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2023.08.01, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.08.02, the highest 'high' price occurred at 08:15 and repeated 1 times.
# On 2023.08.02, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2023.08.03, the highest 'high' price occurred at 19:45 and repeated 1 times.
# On 2023.08.03, the lowest 'low' price occurred at 11:30 and repeated 1 times.
# On 2023.08.04, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2023.08.04, the lowest 'low' price occurred at 15:00 and repeated 1 times.
# On 2023.08.07, the highest 'high' price occurred at 16:30 and repeated 1 times.
# On 2023.08.07, the lowest 'low' price occurred at 13:00 and repeated 1 times.
# On 2023.08.08, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2023.08.08, the lowest 'low' price occurred at 17:00 and repeated 1 times.
# On 2023.08.09, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2023.08.09, the lowest 'low' price occurred at 15:15 and repeated 1 times.
# On 2023.08.10, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2023.08.10, the lowest 'low' price occurred at 06:15 and repeated 2 times.
# On 2023.08.11, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2023.08.11, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2023.08.14, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2023.08.14, the lowest 'low' price occurred at 16:45 and repeated 1 times.
# On 2023.08.15, the highest 'high' price occurred at 16:15 and repeated 1 times.
# On 2023.08.15, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2023.08.16, the highest 'high' price occurred at 11:30 and repeated 1 times.
# On 2023.08.16, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2023.08.17, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2023.08.17, the lowest 'low' price occurred at 06:45 and repeated 2 times.
# On 2023.08.18, the highest 'high' price occurred at 06:30 and repeated 1 times.
# On 2023.08.18, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2023.08.21, the highest 'high' price occurred at 14:45 and repeated 1 times.
# On 2023.08.21, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2023.08.22, the highest 'high' price occurred at 10:45 and repeated 1 times.
# On 2023.08.22, the lowest 'low' price occurred at 17:30 and repeated 1 times.
# On 2023.08.23, the highest 'high' price occurred at 10:15 and repeated 1 times.
# On 2023.08.23, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.08.24, the highest 'high' price occurred at 08:30 and repeated 1 times.
# On 2023.08.24, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.08.25, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2023.08.25, the lowest 'low' price occurred at 17:45 and repeated 1 times.
# On 2023.08.28, the highest 'high' price occurred at 13:30 and repeated 1 times.
# On 2023.08.28, the lowest 'low' price occurred at 17:00 and repeated 1 times.
# On 2023.08.29, the highest 'high' price occurred at 20:00 and repeated 1 times.
# On 2023.08.29, the lowest 'low' price occurred at 16:15 and repeated 1 times.
# On 2023.08.30, the highest 'high' price occurred at 16:45 and repeated 1 times.
# On 2023.08.30, the lowest 'low' price occurred at 11:00 and repeated 1 times.
# On 2023.08.31, the highest 'high' price occurred at 09:45 and repeated 1 times.
# On 2023.08.31, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2023.09.01, the highest 'high' price occurred at 15:30 and repeated 1 times.
# On 2023.09.01, the lowest 'low' price occurred at 19:30 and repeated 1 times.
# On 2023.09.04, the highest 'high' price occurred at 14:00 and repeated 1 times.
# On 2023.09.04, the lowest 'low' price occurred at 07:15 and repeated 1 times.
# On 2023.09.05, the highest 'high' price occurred at 07:30 and repeated 1 times.
# On 2023.09.05, the lowest 'low' price occurred at 18:00 and repeated 1 times.
# On 2023.09.06, the highest 'high' price occurred at 14:15 and repeated 1 times.
# On 2023.09.06, the lowest 'low' price occurred at 17:00 and repeated 1 times.
# On 2023.09.07, the highest 'high' price occurred at 06:30 and repeated 1 times.
# On 2023.09.07, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.09.08, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2023.09.08, the lowest 'low' price occurred at 14:45 and repeated 1 times.
# On 2023.09.11, the highest 'high' price occurred at 17:15 and repeated 1 times.
# On 2023.09.11, the lowest 'low' price occurred at 15:00 and repeated 1 times.
# On 2023.09.12, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2023.09.12, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2023.09.13, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2023.09.13, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2023.09.14, the highest 'high' price occurred at 08:30 and repeated 1 times.
# On 2023.09.14, the lowest 'low' price occurred at 19:15 and repeated 1 times.
# On 2023.09.15, the highest 'high' price occurred at 17:00 and repeated 1 times.
# On 2023.09.15, the lowest 'low' price occurred at 06:00 and repeated 1 times.
# On 2023.09.18, the highest 'high' price occurred at 18:45 and repeated 1 times.
# On 2023.09.18, the lowest 'low' price occurred at 16:00 and repeated 1 times.
# On 2023.09.19, the highest 'high' price occurred at 15:15 and repeated 1 times.
# On 2023.09.19, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2023.09.20, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2023.09.20, the lowest 'low' price occurred at 09:00 and repeated 1 times.
# On 2023.09.21, the highest 'high' price occurred at 17:30 and repeated 1 times.
# On 2023.09.21, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2023.09.22, the highest 'high' price occurred at 17:30 and repeated 1 times.
# On 2023.09.22, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2023.10.02, the highest 'high' price occurred at 10:00 and repeated 1 times.
# On 2023.10.02, the lowest 'low' price occurred at 19:45 and repeated 1 times.
# On 2023.10.03, the highest 'high' price occurred at 11:15 and repeated 1 times.
# On 2023.10.03, the lowest 'low' price occurred at 18:45 and repeated 1 times.
# On 2023.10.04, the highest 'high' price occurred at 15:45 and repeated 1 times.
# On 2023.10.04, the lowest 'low' price occurred at 10:00 and repeated 1 times.
# On 2023.10.05, the highest 'high' price occurred at 19:30 and repeated 1 times.
# On 2023.10.05, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2023.10.06, the highest 'high' price occurred at 18:30 and repeated 1 times.
# On 2023.10.06, the lowest 'low' price occurred at 15:45 and repeated 1 times.
# On 2023.10.09, the highest 'high' price occurred at 06:00 and repeated 1 times.
# On 2023.10.09, the lowest 'low' price occurred at 10:45 and repeated 1 times.
# On 2023.10.10, the highest 'high' price occurred at 19:00 and repeated 1 times.
# On 2023.10.10, the lowest 'low' price occurred at 10:15 and repeated 1 times.
# On 2023.10.11, the highest 'high' price occurred at 16:45 and repeated 1 times.
# On 2023.10.11, the lowest 'low' price occurred at 15:30 and repeated 1 times.
# On 2023.10.12, the highest 'high' price occurred at 09:30 and repeated 1 times.
# On 2023.10.12, the lowest 'low' price occurred at 20:00 and repeated 1 times.
# On 2023.10.13, the highest 'high' price occurred at 11:00 and repeated 1 times.
# On 2023.10.13, the lowest 'low' price occurred at 18:00 and repeated 1 times.

# %%
# Create a dictionary to store the count of events for each hour and time interval
hourly_event_counts = {}

# Iterate through the filtered data
for hour in range(6, 21):
    # Initialize the counts for each time interval
    counts = {
        'HH:00-HH:04': 0,
        'HH:05-HH:09': 0,
        'HH:10-HH:19': 0,
        'HH:20-HH:29': 0,
        'HH:30-HH:39': 0,
        'HH:40-HH:49': 0,
        'HH:50-HH:59': 0
    }

    # Filter the data for the current hour
    hour_data = filtered_df[filtered_df['datetime'].dt.hour == hour]

    # Iterate through each row in the filtered data
    for _, row in hour_data.iterrows():
        time_minute = row['datetime'].minute
        if 0 <= time_minute <= 4:
            counts['HH:00-HH:04'] += 1
        elif 5 <= time_minute <= 9:
            counts['HH:05-HH:09'] += 1
        elif 10 <= time_minute <= 19:
            counts['HH:10-HH:19'] += 1
        elif 20 <= time_minute <= 29:
            counts['HH:20-HH:29'] += 1
        elif 30 <= time_minute <= 39:
            counts['HH:30-HH:39'] += 1
        elif 40 <= time_minute <= 49:
            counts['HH:30-HH:39'] += 1
        else:
            counts['HH:50-HH:59'] += 1

    # Store the counts in the dictionary
    hourly_event_counts[f'Hour {hour}'] = counts

# Print the results
for hour, counts in hourly_event_counts.items():
    print(f'For {hour}:')
    for interval, count in counts.items():
        print(f'{interval}: {count} times')
# Out:
# For Hour 6:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 7:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 8:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 9:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 10:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 11:
# HH:00-HH:04: 224 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 12:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 13:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 14:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 15:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 901 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 16:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 449 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 17:
# HH:00-HH:04: 223 times
# HH:05-HH:09: 220 times
# HH:10-HH:19: 440 times
# HH:20-HH:29: 440 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 18:
# HH:00-HH:04: 225 times
# HH:05-HH:09: 225 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 443 times
# HH:30-HH:39: 892 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 443 times
# For Hour 19:
# HH:00-HH:04: 223 times
# HH:05-HH:09: 227 times
# HH:10-HH:19: 460 times
# HH:20-HH:29: 458 times
# HH:30-HH:39: 920 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 460 times
# For Hour 20:
# HH:00-HH:04: 46 times
# HH:05-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times

# %%
import pandas as pd

# Assuming you have loaded and filtered your data as "filtered_df" as per the previous steps

# Combine the date and time columns into a single datetime column
filtered_df['datetime'] = pd.to_datetime(filtered_df['date'] + ' ' + filtered_df['time'])

# Group the data by date
grouped = filtered_df.groupby('date')

# Define the time ranges
time_ranges = [
    ("06:00", "06:04"),
    ("06:05", "06:09"),
    ("06:10", "06:14"),
    ("06:15", "06:19"),
    ("06:20", "06:24"),
    ("06:25", "06:29"),
    ("06:30", "06:34"),
    ("06:35", "06:39"),
    ("06:40", "06:44"),
    ("06:45", "06:49"),
    ("06:50", "06:54"),
    ("06:50", "06:59"),
    ("07:00", "07:04"),
    ("07:05", "07:09"),
    ("07:10", "07:14"),
    ("07:15", "07:19"),
    ("07:20", "07:24"),
    ("07:25", "07:29"),
    ("07:30", "07:34"),
    ("07:35", "07:39"),
    ("07:40", "07:44"),
    ("07:45", "07:49"),
    ("07:50", "07:54"),
    ("07:50", "07:59"),
    ("08:00", "08:04"),
    ("08:05", "08:09"),
    ("08:10", "08:14"),
    ("08:15", "08:19"),
    ("08:20", "08:24"),
    ("08:25", "08:29"),
    ("08:30", "08:34"),
    ("08:35", "08:39"),
    ("08:40", "08:44"),
    ("08:45", "08:49"),
    ("08:50", "08:54"),
    ("08:50", "08:59"),
    ("09:00", "09:04"),
    ("09:05", "09:09"),
    ("09:10", "09:14"),
    ("09:15", "09:19"),
    ("09:20", "09:24"),
    ("09:25", "09:29"),
    ("09:30", "09:34"),
    ("09:35", "09:39"),
    ("09:40", "09:44"),
    ("09:45", "09:49"),
    ("09:50", "09:54"),
    ("09:50", "09:59"),
]

# Initialize a dictionary to store the counts for each time range
time_range_counts = {time_range: [] for time_range in time_ranges}

# Iterate through each group (day)
for date, group in grouped:
    # Count occurrences in each time range
    for start_time, end_time in time_ranges:
        count = len(group[(group['time'] >= start_time) & (group['time'] <= end_time)])
        time_range_counts[(start_time, end_time)].append(count)

# Calculate the total count for each time range across all days
total_counts = {time_range: sum(counts) for time_range, counts in time_range_counts.items()}

# Sort the results from biggest to lowest
sorted_results = sorted(total_counts.items(), key=lambda x: x[1], reverse=True)

# Print the sorted results
for time_range, total_count in sorted_results:
    print(f"From {time_range[0]} to {time_range[1]} occurred {total_count} times across all days.")
# Out:
# <ipython-input-55-1df9fb5d4dff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['datetime'] = pd.to_datetime(filtered_df['date'] + ' ' + filtered_df['time'])
# From 06:50 to 06:59 occurred 450 times across all days.
# From 07:50 to 07:59 occurred 450 times across all days.
# From 08:50 to 08:59 occurred 450 times across all days.
# From 09:50 to 09:59 occurred 450 times across all days.
# From 06:00 to 06:04 occurred 225 times across all days.
# From 06:05 to 06:09 occurred 225 times across all days.
# From 06:10 to 06:14 occurred 225 times across all days.
# From 06:15 to 06:19 occurred 225 times across all days.
# From 06:20 to 06:24 occurred 225 times across all days.
# From 06:25 to 06:29 occurred 225 times across all days.
# From 06:30 to 06:34 occurred 225 times across all days.
# From 06:35 to 06:39 occurred 225 times across all days.
# From 06:40 to 06:44 occurred 225 times across all days.
# From 06:45 to 06:49 occurred 225 times across all days.
# From 06:50 to 06:54 occurred 225 times across all days.
# From 07:00 to 07:04 occurred 225 times across all days.
# From 07:05 to 07:09 occurred 225 times across all days.
# From 07:10 to 07:14 occurred 225 times across all days.
# From 07:15 to 07:19 occurred 225 times across all days.
# From 07:20 to 07:24 occurred 225 times across all days.
# From 07:25 to 07:29 occurred 225 times across all days.
# From 07:30 to 07:34 occurred 225 times across all days.
# From 07:35 to 07:39 occurred 225 times across all days.
# From 07:40 to 07:44 occurred 225 times across all days.
# From 07:45 to 07:49 occurred 225 times across all days.
# From 07:50 to 07:54 occurred 225 times across all days.
# From 08:00 to 08:04 occurred 225 times across all days.
# From 08:05 to 08:09 occurred 225 times across all days.
# From 08:10 to 08:14 occurred 225 times across all days.
# From 08:15 to 08:19 occurred 225 times across all days.
# From 08:20 to 08:24 occurred 225 times across all days.
# From 08:25 to 08:29 occurred 225 times across all days.
# From 08:30 to 08:34 occurred 225 times across all days.
# From 08:35 to 08:39 occurred 225 times across all days.
# From 08:40 to 08:44 occurred 225 times across all days.
# From 08:45 to 08:49 occurred 225 times across all days.
# From 08:50 to 08:54 occurred 225 times across all days.
# From 09:00 to 09:04 occurred 225 times across all days.
# From 09:05 to 09:09 occurred 225 times across all days.
# From 09:10 to 09:14 occurred 225 times across all days.
# From 09:15 to 09:19 occurred 225 times across all days.
# From 09:20 to 09:24 occurred 225 times across all days.
# From 09:25 to 09:29 occurred 225 times across all days.
# From 09:30 to 09:34 occurred 225 times across all days.
# From 09:35 to 09:39 occurred 225 times across all days.
# From 09:40 to 09:44 occurred 225 times across all days.
# From 09:45 to 09:49 occurred 225 times across all days.
# From 09:50 to 09:54 occurred 225 times across all days.

# %%
import pandas as pd

# Assuming you have loaded and filtered your data as "filtered_df" as per the previous steps

# Combine the date and time columns into a single datetime column
filtered_df['datetime'] = pd.to_datetime(filtered_df['date'] + ' ' + filtered_df['time'])

# Group the data by date
grouped = filtered_df.groupby('date')

# Define the time ranges for each hour
time_ranges = []
for hour in range(6, 20):
    for minute in range(0, 60, 5):
        start_time = f"{hour:02d}:{minute:02d}"
        end_minute = minute + 4 if minute < 55 else 59
        end_time = f"{hour:02d}:{end_minute:02d}"
        time_ranges.append((start_time, end_time))

# Initialize a dictionary to store the counts for each time range
time_range_counts = {time_range: [] for time_range in time_ranges}

# Iterate through each group (day)
for date, group in grouped:
    # Count occurrences in each time range
    for start_time, end_time in time_ranges:
        count = len(group[(group['time'] >= start_time) & (group['time'] <= end_time)])
        time_range_counts[(start_time, end_time)].append(count)

# Calculate the total count for each time range across all days
total_counts = {time_range: sum(counts) for time_range, counts in time_range_counts.items()}

# Sort the results from biggest to lowest
sorted_results = sorted(total_counts.items(), key=lambda x: x[1], reverse=True)

# Print the sorted results
for time_range, total_count in sorted_results:
    print(f"From {time_range[0]} to {time_range[1]} occurred {total_count} times across all days.")
# Out:
# <ipython-input-56-a833b612c192>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['datetime'] = pd.to_datetime(filtered_df['date'] + ' ' + filtered_df['time'])
# From 19:10 to 19:14 occurred 230 times across all days.
# From 19:15 to 19:19 occurred 230 times across all days.
# From 19:25 to 19:29 occurred 230 times across all days.
# From 19:30 to 19:34 occurred 230 times across all days.
# From 19:35 to 19:39 occurred 230 times across all days.
# From 19:40 to 19:44 occurred 230 times across all days.
# From 19:45 to 19:49 occurred 230 times across all days.
# From 19:50 to 19:54 occurred 230 times across all days.
# From 19:55 to 19:59 occurred 230 times across all days.
# From 19:20 to 19:24 occurred 228 times across all days.
# From 19:05 to 19:09 occurred 227 times across all days.
# From 15:40 to 15:44 occurred 226 times across all days.
# From 06:00 to 06:04 occurred 225 times across all days.
# From 06:05 to 06:09 occurred 225 times across all days.
# From 06:10 to 06:14 occurred 225 times across all days.
# From 06:15 to 06:19 occurred 225 times across all days.
# From 06:20 to 06:24 occurred 225 times across all days.
# From 06:25 to 06:29 occurred 225 times across all days.
# From 06:30 to 06:34 occurred 225 times across all days.
# From 06:35 to 06:39 occurred 225 times across all days.
# From 06:40 to 06:44 occurred 225 times across all days.
# From 06:45 to 06:49 occurred 225 times across all days.
# From 06:50 to 06:54 occurred 225 times across all days.
# From 06:55 to 06:59 occurred 225 times across all days.
# From 07:00 to 07:04 occurred 225 times across all days.
# From 07:05 to 07:09 occurred 225 times across all days.
# From 07:10 to 07:14 occurred 225 times across all days.
# From 07:15 to 07:19 occurred 225 times across all days.
# From 07:20 to 07:24 occurred 225 times across all days.
# From 07:25 to 07:29 occurred 225 times across all days.
# From 07:30 to 07:34 occurred 225 times across all days.
# From 07:35 to 07:39 occurred 225 times across all days.
# From 07:40 to 07:44 occurred 225 times across all days.
# From 07:45 to 07:49 occurred 225 times across all days.
# From 07:50 to 07:54 occurred 225 times across all days.
# From 07:55 to 07:59 occurred 225 times across all days.
# From 08:00 to 08:04 occurred 225 times across all days.
# From 08:05 to 08:09 occurred 225 times across all days.
# From 08:10 to 08:14 occurred 225 times across all days.
# From 08:15 to 08:19 occurred 225 times across all days.
# From 08:20 to 08:24 occurred 225 times across all days.
# From 08:25 to 08:29 occurred 225 times across all days.
# From 08:30 to 08:34 occurred 225 times across all days.
# From 08:35 to 08:39 occurred 225 times across all days.
# From 08:40 to 08:44 occurred 225 times across all days.
# From 08:45 to 08:49 occurred 225 times across all days.
# From 08:50 to 08:54 occurred 225 times across all days.
# From 08:55 to 08:59 occurred 225 times across all days.
# From 09:00 to 09:04 occurred 225 times across all days.
# From 09:05 to 09:09 occurred 225 times across all days.
# From 09:10 to 09:14 occurred 225 times across all days.
# From 09:15 to 09:19 occurred 225 times across all days.
# From 09:20 to 09:24 occurred 225 times across all days.
# From 09:25 to 09:29 occurred 225 times across all days.
# From 09:30 to 09:34 occurred 225 times across all days.
# From 09:35 to 09:39 occurred 225 times across all days.
# From 09:40 to 09:44 occurred 225 times across all days.
# From 09:45 to 09:49 occurred 225 times across all days.
# From 09:50 to 09:54 occurred 225 times across all days.
# From 09:55 to 09:59 occurred 225 times across all days.
# From 10:00 to 10:04 occurred 225 times across all days.
# From 10:05 to 10:09 occurred 225 times across all days.
# From 10:10 to 10:14 occurred 225 times across all days.
# From 10:15 to 10:19 occurred 225 times across all days.
# From 10:20 to 10:24 occurred 225 times across all days.
# From 10:25 to 10:29 occurred 225 times across all days.
# From 10:30 to 10:34 occurred 225 times across all days.
# From 10:35 to 10:39 occurred 225 times across all days.
# From 10:40 to 10:44 occurred 225 times across all days.
# From 10:45 to 10:49 occurred 225 times across all days.
# From 10:50 to 10:54 occurred 225 times across all days.
# From 10:55 to 10:59 occurred 225 times across all days.
# From 11:05 to 11:09 occurred 225 times across all days.
# From 11:10 to 11:14 occurred 225 times across all days.
# From 11:15 to 11:19 occurred 225 times across all days.
# From 11:20 to 11:24 occurred 225 times across all days.
# From 11:25 to 11:29 occurred 225 times across all days.
# From 11:30 to 11:34 occurred 225 times across all days.
# From 11:35 to 11:39 occurred 225 times across all days.
# From 11:40 to 11:44 occurred 225 times across all days.
# From 11:45 to 11:49 occurred 225 times across all days.
# From 11:50 to 11:54 occurred 225 times across all days.
# From 11:55 to 11:59 occurred 225 times across all days.
# From 12:00 to 12:04 occurred 225 times across all days.
# From 12:05 to 12:09 occurred 225 times across all days.
# From 12:10 to 12:14 occurred 225 times across all days.
# From 12:15 to 12:19 occurred 225 times across all days.
# From 12:20 to 12:24 occurred 225 times across all days.
# From 12:25 to 12:29 occurred 225 times across all days.
# From 12:30 to 12:34 occurred 225 times across all days.
# From 12:35 to 12:39 occurred 225 times across all days.
# From 12:40 to 12:44 occurred 225 times across all days.
# From 12:45 to 12:49 occurred 225 times across all days.
# From 12:50 to 12:54 occurred 225 times across all days.
# From 12:55 to 12:59 occurred 225 times across all days.
# From 13:00 to 13:04 occurred 225 times across all days.
# From 13:05 to 13:09 occurred 225 times across all days.
# From 13:10 to 13:14 occurred 225 times across all days.
# From 13:15 to 13:19 occurred 225 times across all days.
# From 13:20 to 13:24 occurred 225 times across all days.
# From 13:25 to 13:29 occurred 225 times across all days.
# From 13:30 to 13:34 occurred 225 times across all days.
# From 13:35 to 13:39 occurred 225 times across all days.
# From 13:40 to 13:44 occurred 225 times across all days.
# From 13:45 to 13:49 occurred 225 times across all days.
# From 13:50 to 13:54 occurred 225 times across all days.
# From 13:55 to 13:59 occurred 225 times across all days.
# From 14:00 to 14:04 occurred 225 times across all days.
# From 14:05 to 14:09 occurred 225 times across all days.
# From 14:10 to 14:14 occurred 225 times across all days.
# From 14:15 to 14:19 occurred 225 times across all days.
# From 14:20 to 14:24 occurred 225 times across all days.
# From 14:25 to 14:29 occurred 225 times across all days.
# From 14:30 to 14:34 occurred 225 times across all days.
# From 14:35 to 14:39 occurred 225 times across all days.
# From 14:40 to 14:44 occurred 225 times across all days.
# From 14:45 to 14:49 occurred 225 times across all days.
# From 14:50 to 14:54 occurred 225 times across all days.
# From 14:55 to 14:59 occurred 225 times across all days.
# From 15:00 to 15:04 occurred 225 times across all days.
# From 15:05 to 15:09 occurred 225 times across all days.
# From 15:10 to 15:14 occurred 225 times across all days.
# From 15:15 to 15:19 occurred 225 times across all days.
# From 15:20 to 15:24 occurred 225 times across all days.
# From 15:25 to 15:29 occurred 225 times across all days.
# From 15:30 to 15:34 occurred 225 times across all days.
# From 15:35 to 15:39 occurred 225 times across all days.
# From 15:45 to 15:49 occurred 225 times across all days.
# From 15:50 to 15:54 occurred 225 times across all days.
# From 15:55 to 15:59 occurred 225 times across all days.
# From 16:00 to 16:04 occurred 225 times across all days.
# From 16:05 to 16:09 occurred 225 times across all days.
# From 16:10 to 16:14 occurred 225 times across all days.
# From 16:15 to 16:19 occurred 225 times across all days.
# From 16:20 to 16:24 occurred 225 times across all days.
# From 16:30 to 16:34 occurred 225 times across all days.
# From 16:35 to 16:39 occurred 225 times across all days.
# From 16:40 to 16:44 occurred 225 times across all days.
# From 16:45 to 16:49 occurred 225 times across all days.
# From 16:50 to 16:54 occurred 225 times across all days.
# From 16:55 to 16:59 occurred 225 times across all days.
# From 17:30 to 17:34 occurred 225 times across all days.
# From 17:35 to 17:39 occurred 225 times across all days.
# From 17:40 to 17:44 occurred 225 times across all days.
# From 17:45 to 17:49 occurred 225 times across all days.
# From 17:50 to 17:54 occurred 225 times across all days.
# From 17:55 to 17:59 occurred 225 times across all days.
# From 18:00 to 18:04 occurred 225 times across all days.
# From 18:05 to 18:09 occurred 225 times across all days.
# From 18:10 to 18:14 occurred 225 times across all days.
# From 18:15 to 18:19 occurred 225 times across all days.
# From 18:40 to 18:44 occurred 225 times across all days.
# From 18:45 to 18:49 occurred 225 times across all days.
# From 11:00 to 11:04 occurred 224 times across all days.
# From 16:25 to 16:29 occurred 224 times across all days.
# From 17:00 to 17:04 occurred 223 times across all days.
# From 18:25 to 18:29 occurred 223 times across all days.
# From 18:50 to 18:54 occurred 223 times across all days.
# From 19:00 to 19:04 occurred 223 times across all days.
# From 18:35 to 18:39 occurred 222 times across all days.
# From 17:05 to 17:09 occurred 220 times across all days.
# From 17:10 to 17:14 occurred 220 times across all days.
# From 17:15 to 17:19 occurred 220 times across all days.
# From 17:20 to 17:24 occurred 220 times across all days.
# From 17:25 to 17:29 occurred 220 times across all days.
# From 18:20 to 18:24 occurred 220 times across all days.
# From 18:30 to 18:34 occurred 220 times across all days.
# From 18:55 to 18:59 occurred 220 times across all days.

# %%
("02:00", "02:05"),

2:33 - 3:00
4:03 - 4:30
8:50 - 9:10
9:50 - 10:10
10:50 - 11:10
11:50 - 12:10
13:10 - 13:40
15:15 - 15:45

0142-0200
0212-0230
0242-0300
0312-0330
0342-0400
0412-0430
0442-0500
0512-0530
0542-0600
0612-0630
0642-0700
0712-0730
0742-0800
0812-0830
0842-0900
0912-0930
0942-1000
1012-1030
1042-1100
1112-1130
1142-1200
1400-1500
# Out:
#   File "<ipython-input-57-a0d8ec549b82>", line 4
#     4:03 - 4:30
#       ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import pandas as pd

# Assuming you have loaded and filtered your data as "filtered_df" as per the previous steps

# Combine the date and time columns into a single datetime column
filtered_df['datetime'] = pd.to_datetime(filtered_df['date'] + ' ' + filtered_df['time'])

# Group the data by date
grouped = filtered_df.groupby('date')

# Define the time ranges
time_ranges = [
    ("10:00", "10:04"),
    ("10:05", "10:10"),
    ("10:10", "10:14"),
    ("10:15", "10:19"),
    ("10:20", "10:24"),
    ("10:25", "10:29"),
    ("10:30", "10:34"),
    ("10:35", "10:39"),
    ("10:40", "10:44"),
    ("10:45", "10:49"),
    ("10:50", "10:54"),
    ("10:50", "10:59"),
    ("11:00", "11:04"),
    ("11:05", "11:11"),
    ("11:11", "11:14"),
    ("11:15", "11:19"),
    ("11:20", "11:24"),
    ("11:25", "11:29"),
    ("11:30", "11:34"),
    ("11:35", "11:39"),
    ("11:40", "11:44"),
    ("11:45", "11:49"),
    ("11:50", "11:54"),
    ("11:50", "11:59"),
    ("12:00", "12:04"),
    ("12:05", "12:12"),
    ("12:12", "12:14"),
    ("12:15", "12:19"),
    ("12:20", "12:24"),
    ("12:25", "12:29"),
    ("12:30", "12:34"),
    ("12:35", "12:39"),
    ("12:40", "12:44"),
    ("12:45", "12:49"),
    ("12:50", "12:54"),
    ("12:50", "12:59"),
    ("13:00", "13:04"),
    ("13:05", "13:13"),
    ("13:13", "13:14"),
    ("13:15", "13:19"),
    ("13:20", "13:24"),
    ("13:25", "13:29"),
    ("13:30", "13:34"),
    ("13:35", "13:39"),
    ("13:40", "13:44"),
    ("13:45", "13:49"),
    ("13:50", "13:54"),
    ("13:50", "13:59"),
    ("14:00", "14:04"),
    ("14:05", "14:14"),
    ("14:14", "14:14"),
    ("14:15", "14:19"),
    ("14:20", "14:24"),
    ("14:25", "14:29"),
    ("14:30", "14:34"),
    ("14:35", "14:39"),
    ("14:40", "14:44"),
    ("14:45", "14:49"),
    ("14:50", "14:54"),
    ("14:50", "14:59"),
    ("15:00", "15:04"),
    ("15:05", "15:15"),
    ("15:15", "15:15"),
    ("15:15", "15:19"),
    ("15:20", "15:24"),
    ("15:25", "15:29"),
    ("15:30", "15:34"),
    ("15:35", "15:39"),
    ("15:40", "15:44"),
    ("15:45", "15:49"),
    ("15:50", "15:54"),
    ("15:50", "15:59"),
]

# Initialize a dictionary to store the counts for each time range
time_range_counts = {time_range: [] for time_range in time_ranges}

# Iterate through each group (day)
for date, group in grouped:
    # Count occurrences in each time range
    for start_time, end_time in time_ranges:
        count = len(group[(group['time'] >= start_time) & (group['time'] <= end_time)])
        time_range_counts[(start_time, end_time)].append(count)

# Calculate the total count for each time range across all days
total_counts = {time_range: sum(counts) for time_range, counts in time_range_counts.items()}

# Sort the results from biggest to lowest
sorted_results = sorted(total_counts.items(), key=lambda x: x[1], reverse=True)

# Print the sorted results
for time_range, total_count in sorted_results:
    print(f"From {time_range[0]} to {time_range[1]} occurred {total_count} times across all days.")

# %%
import pandas as pd

# Assuming you have loaded and filtered your data as "filtered_df" as per the previous steps

# Combine the date and time columns into a single datetime column
filtered_df['datetime'] = pd.to_datetime(filtered_df['date'] + ' ' + filtered_df['time'])

# Group the data by date
grouped = filtered_df.groupby('date')

# Define the time ranges
time_ranges = [
    ("16:00", "16:04"),
    ("16:05", "16:10"),
    ("16:10", "16:14"),
    ("16:15", "16:19"),
    ("16:20", "16:24"),
    ("16:25", "16:29"),
    ("16:30", "16:34"),
    ("16:35", "16:39"),
    ("16:40", "16:44"),
    ("16:45", "16:49"),
    ("16:50", "16:54"),
    ("16:50", "16:59"),
    ("17:00", "17:04"),
    ("17:05", "17:11"),
    ("17:11", "17:14"),
    ("17:15", "17:19"),
    ("17:20", "17:24"),
    ("17:25", "17:29"),
    ("17:30", "17:34"),
    ("17:35", "17:39"),
    ("17:40", "17:44"),
    ("17:45", "17:49"),
    ("17:50", "17:54"),
    ("17:50", "17:59"),
    ("18:00", "18:04"),
    ("18:05", "18:12"),
    ("18:12", "18:14"),
    ("18:15", "18:19"),
    ("18:20", "18:24"),
    ("18:25", "18:29"),
    ("18:30", "18:34"),
    ("18:35", "18:39"),
    ("18:40", "18:44"),
    ("18:45", "18:49"),
    ("18:50", "18:54"),
    ("18:50", "18:59"),
    ("19:00", "19:04"),
    ("19:05", "19:13"),
    ("19:13", "19:14"),
    ("19:15", "19:19"),
    ("19:20", "19:24"),
    ("19:25", "19:29"),
    ("19:30", "19:34"),
    ("19:35", "19:39"),
    ("19:40", "19:44"),
    ("19:45", "19:49"),
    ("19:50", "19:54"),
    ("19:50", "19:59"),
]

# Initialize a dictionary to store the counts for each time range
time_range_counts = {time_range: [] for time_range in time_ranges}

# Iterate through each group (day)
for date, group in grouped:
    # Count occurrences in each time range
    for start_time, end_time in time_ranges:
        count = len(group[(group['time'] >= start_time) & (group['time'] <= end_time)])
        time_range_counts[(start_time, end_time)].append(count)

# Calculate the total count for each time range across all days
total_counts = {time_range: sum(counts) for time_range, counts in time_range_counts.items()}

# Sort the results from biggest to lowest
sorted_results = sorted(total_counts.items(), key=lambda x: x[1], reverse=True)

# Print the sorted results
for time_range, total_count in sorted_results:
    print(f"From {time_range[0]} to {time_range[1]} occurred {total_count} times across all days.")

# %%
#LONDON

# From 06:50 to 06:59 occurred 450 times across all days.
# From 07:50 to 07:59 occurred 450 times across all days.
# From 08:50 to 08:59 occurred 450 times across all days.
# From 09:50 to 09:59 occurred 450 times across all days.

#NY AM

# From 15:05 to 15:15 occurred 495 times across all days.
# From 10:50 to 10:59 occurred 450 times across all days.
# From 11:50 to 11:59 occurred 450 times across all days.
# From 12:50 to 12:59 occurred 450 times across all days.
# From 13:50 to 13:59 occurred 450 times across all days.
# From 14:05 to 14:14 occurred 450 times across all days.
# From 14:50 to 14:59 occurred 450 times across all days.
# From 15:50 to 15:59 occurred 450 times across all days.

# NY PM

# From 19:50 to 19:59 occurred 460 times across all days.
# From 16:50 to 16:59 occurred 450 times across all days.
# From 17:50 to 17:59 occurred 450 times across all days.
# From 18:50 to 18:59 occurred 443 times across all days.
# From 19:05 to 19:13 occurred 411 times across all days.

# %%
00:00
00:23 q2
00:45
01:08

01:30
01:53 q2
02:15
02:38

03:00
03:23 q2
03:45
04:08

04:30
04:53 q2
05:15
05:38

06:00
06:23 q2
06:45
07:08

07:30
07:53 q2
08:15
08:38

09:00
09:23 q2
09:45
10:08

10:30
10:53 q2
11:15
11:38

12:00

# %%
from google.colab import drive
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
import pytz

drive.mount('/content/drive')

file_path = '/content/drive/My Drive/EURUSDM52023.csv'

# Read the CSV file into a DataFrame without column names
df = pd.read_csv(file_path, header=None)

# Rename the columns
df.columns = ['date', 'time', 'open', 'high', 'low', 'close', 'volume']

# Combine the 'date' and 'time' columns into a single datetime column
def convert_to_utc_minus_4(row):
    dt = datetime.strptime(row['date'] + ' ' + row['time'], '%Y.%m.%d %H:%M')
    dt = dt - relativedelta(hours=4)  # Subtract 4 hours to convert to UTC-4
    return dt

df['datetime'] = df.apply(convert_to_utc_minus_4, axis=1)

# # Drop the 'date' and 'time' columns if needed
df.drop(['date', 'time'], axis=1, inplace=True)

# Reorder the columns if needed
# df = df[['datetime', 'open', 'high', 'low', 'close', 'volume']]

# Split the 'datetime' column into 'date' and 'time' columns
df['date'] = df['datetime'].dt.date
df['time'] = df['datetime'].dt.time

# Reorder the columns if needed
df = df[['datetime', 'date', 'time', 'open', 'high', 'low', 'close', 'volume']]

# Now, 'datetime' column contains the date and time in UTC-4 time zone
# df

start_time = pd.to_datetime('02:00')
end_time = pd.to_datetime('05:00')
filtered_df = df[(df['datetime'].dt.time >= start_time.time()) & (df['datetime'].dt.time <= end_time.time())]

filtered_df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                  datetime        date      time     open     high      low  \
# 210   2022-12-05 02:00:00  2022-12-05  02:00:00  1.05804  1.05808  1.05793
# 211   2022-12-05 02:05:00  2022-12-05  02:05:00  1.05796  1.05819  1.05788
# 212   2022-12-05 02:10:00  2022-12-05  02:10:00  1.05815  1.05833  1.05813
# 213   2022-12-05 02:15:00  2022-12-05  02:15:00  1.05823  1.05827  1.05796
# 214   2022-12-05 02:20:00  2022-12-05  02:20:00  1.05806  1.05810  1.05791
# ...                   ...         ...       ...      ...      ...      ...
# 64917 2023-10-17 04:40:00  2023-10-17  04:40:00  1.05460  1.05468  1.05443
# 64918 2023-10-17 04:45:00  2023-10-17  04:45:00  1.05454  1.05462  1.05448
# 64919 2023-10-17 04:50:00  2023-10-17  04:50:00  1.05459  1.05470  1.05451
# 64920 2023-10-17 04:55:00  2023-10-17  04:55:00  1.05462  1.05462  1.05436
# 64921 2023-10-17 05:00:00  2023-10-17  05:00:00  1.05447  1.05450  1.05420
#
#          close  volume
# 210    1.05796     184
# 211    1.05815     137
# 212    1.05826     138
# 213    1.05806      84
# 214    1.05794      81
# ...        ...     ...
# 64917  1.05453     124
# 64918  1.05458     105
# 64919  1.05463     196
# 64920  1.05440     328
# 64921  1.05431     484
#
# [8351 rows x 8 columns]

# %%
# Assuming you have loaded and filtered your data as "filtered_df" as per the previous steps

# Group the data by date
grouped = filtered_df.groupby('date')

# Initialize dictionaries to store the results
max_high_times = {}
min_low_times = {}
max_high_counts = {}
min_low_counts = {}

# Iterate through each group (day)
for date, group in grouped:
    # Find the row with the highest "high" and lowest "low" for the day
    max_high_row = group[group['high'] == group['high'].max()]
    min_low_row = group[group['low'] == group['low'].min()]

    # Extract the times from the rows
    max_high_time = max_high_row['time'].iloc[0]
    min_low_time = min_low_row['time'].iloc[0]

    # Calculate how many times each event occurred for the day
    count_max_high = len(group[group['high'] == group['high'].max()])
    count_min_low = len(group[group['low'] == group['low'].min()])

    # Store the results in dictionaries
    max_high_times[date] = max_high_time
    min_low_times[date] = min_low_time
    max_high_counts[date] = count_max_high
    min_low_counts[date] = count_min_low

# Print the results
for date in grouped.groups.keys():
    print(f"On {date}, the highest 'high' price occurred at {max_high_times[date]} and repeated {max_high_counts[date]} times.")
    print(f"On {date}, the lowest 'low' price occurred at {min_low_times[date]} and repeated {min_low_counts[date]} times.")
# Out:
# On 2022-12-05, the highest 'high' price occurred at 03:30:00 and repeated 2 times.
# On 2022-12-05, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-06, the highest 'high' price occurred at 02:20:00 and repeated 1 times.
# On 2022-12-06, the lowest 'low' price occurred at 04:20:00 and repeated 2 times.
# On 2022-12-07, the highest 'high' price occurred at 03:15:00 and repeated 1 times.
# On 2022-12-07, the lowest 'low' price occurred at 04:30:00 and repeated 3 times.
# On 2022-12-08, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2022-12-08, the lowest 'low' price occurred at 03:25:00 and repeated 1 times.
# On 2022-12-09, the highest 'high' price occurred at 03:20:00 and repeated 1 times.
# On 2022-12-09, the lowest 'low' price occurred at 04:50:00 and repeated 1 times.
# On 2022-12-12, the highest 'high' price occurred at 04:45:00 and repeated 2 times.
# On 2022-12-12, the lowest 'low' price occurred at 03:10:00 and repeated 1 times.
# On 2022-12-13, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-13, the lowest 'low' price occurred at 02:20:00 and repeated 1 times.
# On 2022-12-14, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-14, the lowest 'low' price occurred at 02:35:00 and repeated 2 times.
# On 2022-12-15, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2022-12-15, the lowest 'low' price occurred at 03:00:00 and repeated 1 times.
# On 2022-12-16, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-16, the lowest 'low' price occurred at 03:50:00 and repeated 1 times.
# On 2022-12-19, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2022-12-19, the lowest 'low' price occurred at 03:35:00 and repeated 1 times.
# On 2022-12-20, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2022-12-20, the lowest 'low' price occurred at 03:50:00 and repeated 1 times.
# On 2022-12-21, the highest 'high' price occurred at 03:55:00 and repeated 1 times.
# On 2022-12-21, the lowest 'low' price occurred at 02:40:00 and repeated 1 times.
# On 2022-12-22, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2022-12-22, the lowest 'low' price occurred at 02:35:00 and repeated 1 times.
# On 2022-12-23, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-23, the lowest 'low' price occurred at 04:20:00 and repeated 1 times.
# On 2022-12-26, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-26, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-27, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2022-12-27, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2022-12-28, the highest 'high' price occurred at 04:20:00 and repeated 1 times.
# On 2022-12-28, the lowest 'low' price occurred at 02:35:00 and repeated 1 times.
# On 2022-12-29, the highest 'high' price occurred at 03:05:00 and repeated 1 times.
# On 2022-12-29, the lowest 'low' price occurred at 04:40:00 and repeated 1 times.
# On 2022-12-30, the highest 'high' price occurred at 02:35:00 and repeated 2 times.
# On 2022-12-30, the lowest 'low' price occurred at 04:30:00 and repeated 1 times.
# On 2023-01-02, the highest 'high' price occurred at 03:00:00 and repeated 1 times.
# On 2023-01-02, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-01-03, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2023-01-03, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-01-04, the highest 'high' price occurred at 03:05:00 and repeated 1 times.
# On 2023-01-04, the lowest 'low' price occurred at 04:40:00 and repeated 1 times.
# On 2023-01-05, the highest 'high' price occurred at 04:10:00 and repeated 2 times.
# On 2023-01-05, the lowest 'low' price occurred at 03:15:00 and repeated 3 times.
# On 2023-01-06, the highest 'high' price occurred at 02:20:00 and repeated 1 times.
# On 2023-01-06, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-09, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-09, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-01-10, the highest 'high' price occurred at 03:40:00 and repeated 2 times.
# On 2023-01-10, the lowest 'low' price occurred at 04:50:00 and repeated 1 times.
# On 2023-01-11, the highest 'high' price occurred at 03:45:00 and repeated 1 times.
# On 2023-01-11, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-01-12, the highest 'high' price occurred at 03:20:00 and repeated 1 times.
# On 2023-01-12, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-13, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-01-13, the lowest 'low' price occurred at 03:35:00 and repeated 2 times.
# On 2023-01-16, the highest 'high' price occurred at 02:20:00 and repeated 1 times.
# On 2023-01-16, the lowest 'low' price occurred at 04:45:00 and repeated 1 times.
# On 2023-01-17, the highest 'high' price occurred at 04:15:00 and repeated 1 times.
# On 2023-01-17, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-01-18, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-18, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-01-19, the highest 'high' price occurred at 04:35:00 and repeated 3 times.
# On 2023-01-19, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-20, the highest 'high' price occurred at 04:05:00 and repeated 1 times.
# On 2023-01-20, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-23, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-23, the lowest 'low' price occurred at 04:30:00 and repeated 1 times.
# On 2023-01-24, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-01-24, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-01-25, the highest 'high' price occurred at 04:20:00 and repeated 1 times.
# On 2023-01-25, the lowest 'low' price occurred at 03:55:00 and repeated 1 times.
# On 2023-01-26, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-01-26, the lowest 'low' price occurred at 03:10:00 and repeated 1 times.
# On 2023-01-27, the highest 'high' price occurred at 03:55:00 and repeated 1 times.
# On 2023-01-27, the lowest 'low' price occurred at 03:00:00 and repeated 1 times.
# On 2023-01-30, the highest 'high' price occurred at 02:15:00 and repeated 1 times.
# On 2023-01-30, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-01-31, the highest 'high' price occurred at 03:00:00 and repeated 1 times.
# On 2023-01-31, the lowest 'low' price occurred at 04:00:00 and repeated 1 times.
# On 2023-02-01, the highest 'high' price occurred at 04:40:00 and repeated 1 times.
# On 2023-02-01, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-02-02, the highest 'high' price occurred at 02:40:00 and repeated 1 times.
# On 2023-02-02, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-03, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-02-03, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-02-06, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2023-02-06, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-07, the highest 'high' price occurred at 04:20:00 and repeated 2 times.
# On 2023-02-07, the lowest 'low' price occurred at 02:35:00 and repeated 2 times.
# On 2023-02-08, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-02-08, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-09, the highest 'high' price occurred at 04:25:00 and repeated 1 times.
# On 2023-02-09, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-10, the highest 'high' price occurred at 04:05:00 and repeated 1 times.
# On 2023-02-10, the lowest 'low' price occurred at 02:55:00 and repeated 1 times.
# On 2023-02-13, the highest 'high' price occurred at 04:35:00 and repeated 1 times.
# On 2023-02-13, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-02-14, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-14, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-02-15, the highest 'high' price occurred at 03:05:00 and repeated 1 times.
# On 2023-02-15, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-16, the highest 'high' price occurred at 02:30:00 and repeated 1 times.
# On 2023-02-16, the lowest 'low' price occurred at 04:40:00 and repeated 1 times.
# On 2023-02-17, the highest 'high' price occurred at 02:10:00 and repeated 1 times.
# On 2023-02-17, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-20, the highest 'high' price occurred at 04:05:00 and repeated 1 times.
# On 2023-02-20, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-02-21, the highest 'high' price occurred at 03:55:00 and repeated 1 times.
# On 2023-02-21, the lowest 'low' price occurred at 02:20:00 and repeated 1 times.
# On 2023-02-22, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-22, the lowest 'low' price occurred at 03:25:00 and repeated 1 times.
# On 2023-02-23, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2023-02-23, the lowest 'low' price occurred at 03:30:00 and repeated 1 times.
# On 2023-02-24, the highest 'high' price occurred at 03:20:00 and repeated 2 times.
# On 2023-02-24, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-02-27, the highest 'high' price occurred at 03:05:00 and repeated 1 times.
# On 2023-02-27, the lowest 'low' price occurred at 04:40:00 and repeated 1 times.
# On 2023-02-28, the highest 'high' price occurred at 02:00:00 and repeated 2 times.
# On 2023-02-28, the lowest 'low' price occurred at 03:35:00 and repeated 2 times.
# On 2023-03-01, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-03-01, the lowest 'low' price occurred at 02:20:00 and repeated 1 times.
# On 2023-03-02, the highest 'high' price occurred at 02:55:00 and repeated 1 times.
# On 2023-03-02, the lowest 'low' price occurred at 04:10:00 and repeated 1 times.
# On 2023-03-03, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-03-03, the lowest 'low' price occurred at 02:30:00 and repeated 1 times.
# On 2023-03-06, the highest 'high' price occurred at 04:10:00 and repeated 1 times.
# On 2023-03-06, the lowest 'low' price occurred at 04:30:00 and repeated 1 times.
# On 2023-03-07, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-03-07, the lowest 'low' price occurred at 04:50:00 and repeated 2 times.
# On 2023-03-08, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-03-08, the lowest 'low' price occurred at 03:20:00 and repeated 1 times.
# On 2023-03-09, the highest 'high' price occurred at 03:35:00 and repeated 1 times.
# On 2023-03-09, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-03-10, the highest 'high' price occurred at 02:30:00 and repeated 1 times.
# On 2023-03-10, the lowest 'low' price occurred at 04:40:00 and repeated 2 times.
# On 2023-03-13, the highest 'high' price occurred at 04:15:00 and repeated 1 times.
# On 2023-03-13, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-03-14, the highest 'high' price occurred at 04:15:00 and repeated 1 times.
# On 2023-03-14, the lowest 'low' price occurred at 04:40:00 and repeated 1 times.
# On 2023-03-15, the highest 'high' price occurred at 02:15:00 and repeated 1 times.
# On 2023-03-15, the lowest 'low' price occurred at 04:20:00 and repeated 1 times.
# On 2023-03-16, the highest 'high' price occurred at 03:25:00 and repeated 1 times.
# On 2023-03-16, the lowest 'low' price occurred at 02:30:00 and repeated 1 times.
# On 2023-03-17, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-03-17, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-03-20, the highest 'high' price occurred at 04:00:00 and repeated 1 times.
# On 2023-03-20, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-03-21, the highest 'high' price occurred at 04:00:00 and repeated 1 times.
# On 2023-03-21, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-03-22, the highest 'high' price occurred at 03:45:00 and repeated 1 times.
# On 2023-03-22, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-03-23, the highest 'high' price occurred at 04:25:00 and repeated 1 times.
# On 2023-03-23, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-03-24, the highest 'high' price occurred at 03:40:00 and repeated 1 times.
# On 2023-03-24, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-03-27, the highest 'high' price occurred at 02:45:00 and repeated 1 times.
# On 2023-03-27, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-03-28, the highest 'high' price occurred at 02:10:00 and repeated 1 times.
# On 2023-03-28, the lowest 'low' price occurred at 04:20:00 and repeated 2 times.
# On 2023-03-29, the highest 'high' price occurred at 03:30:00 and repeated 1 times.
# On 2023-03-29, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-03-30, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-03-30, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-03-31, the highest 'high' price occurred at 03:00:00 and repeated 1 times.
# On 2023-03-31, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-04-03, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-04-03, the lowest 'low' price occurred at 02:55:00 and repeated 1 times.
# On 2023-04-04, the highest 'high' price occurred at 03:50:00 and repeated 1 times.
# On 2023-04-04, the lowest 'low' price occurred at 04:45:00 and repeated 1 times.
# On 2023-04-05, the highest 'high' price occurred at 02:25:00 and repeated 1 times.
# On 2023-04-05, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-04-06, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-04-06, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-04-07, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-04-07, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-04-10, the highest 'high' price occurred at 02:25:00 and repeated 1 times.
# On 2023-04-10, the lowest 'low' price occurred at 04:10:00 and repeated 1 times.
# On 2023-04-11, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-04-11, the lowest 'low' price occurred at 02:45:00 and repeated 1 times.
# On 2023-04-12, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-04-12, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-04-13, the highest 'high' price occurred at 03:15:00 and repeated 1 times.
# On 2023-04-13, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-04-14, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-04-14, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-04-17, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-04-17, the lowest 'low' price occurred at 03:00:00 and repeated 1 times.
# On 2023-04-18, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-04-18, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-04-19, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-04-19, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-04-20, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-04-20, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-04-21, the highest 'high' price occurred at 02:10:00 and repeated 2 times.
# On 2023-04-21, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-04-24, the highest 'high' price occurred at 02:15:00 and repeated 1 times.
# On 2023-04-24, the lowest 'low' price occurred at 04:50:00 and repeated 1 times.
# On 2023-04-25, the highest 'high' price occurred at 03:20:00 and repeated 1 times.
# On 2023-04-25, the lowest 'low' price occurred at 04:30:00 and repeated 1 times.
# On 2023-04-26, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2023-04-26, the lowest 'low' price occurred at 03:20:00 and repeated 1 times.
# On 2023-04-27, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2023-04-27, the lowest 'low' price occurred at 03:00:00 and repeated 1 times.
# On 2023-04-28, the highest 'high' price occurred at 04:40:00 and repeated 1 times.
# On 2023-04-28, the lowest 'low' price occurred at 04:50:00 and repeated 1 times.
# On 2023-05-01, the highest 'high' price occurred at 03:00:00 and repeated 1 times.
# On 2023-05-01, the lowest 'low' price occurred at 04:30:00 and repeated 1 times.
# On 2023-05-02, the highest 'high' price occurred at 04:35:00 and repeated 1 times.
# On 2023-05-02, the lowest 'low' price occurred at 03:35:00 and repeated 1 times.
# On 2023-05-03, the highest 'high' price occurred at 02:55:00 and repeated 1 times.
# On 2023-05-03, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-05-04, the highest 'high' price occurred at 04:35:00 and repeated 1 times.
# On 2023-05-04, the lowest 'low' price occurred at 03:15:00 and repeated 1 times.
# On 2023-05-05, the highest 'high' price occurred at 04:05:00 and repeated 1 times.
# On 2023-05-05, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-05-08, the highest 'high' price occurred at 04:00:00 and repeated 1 times.
# On 2023-05-08, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-05-09, the highest 'high' price occurred at 03:00:00 and repeated 1 times.
# On 2023-05-09, the lowest 'low' price occurred at 04:10:00 and repeated 1 times.
# On 2023-05-10, the highest 'high' price occurred at 02:40:00 and repeated 1 times.
# On 2023-05-10, the lowest 'low' price occurred at 04:35:00 and repeated 2 times.
# On 2023-05-11, the highest 'high' price occurred at 04:40:00 and repeated 1 times.
# On 2023-05-11, the lowest 'low' price occurred at 03:05:00 and repeated 2 times.
# On 2023-05-12, the highest 'high' price occurred at 04:45:00 and repeated 2 times.
# On 2023-05-12, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-05-15, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-05-15, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-05-16, the highest 'high' price occurred at 02:15:00 and repeated 1 times.
# On 2023-05-16, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-05-17, the highest 'high' price occurred at 02:05:00 and repeated 1 times.
# On 2023-05-17, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-05-18, the highest 'high' price occurred at 02:00:00 and repeated 2 times.
# On 2023-05-18, the lowest 'low' price occurred at 04:50:00 and repeated 1 times.
# On 2023-05-19, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-05-19, the lowest 'low' price occurred at 03:40:00 and repeated 1 times.
# On 2023-05-22, the highest 'high' price occurred at 02:40:00 and repeated 1 times.
# On 2023-05-22, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-05-23, the highest 'high' price occurred at 03:35:00 and repeated 2 times.
# On 2023-05-23, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-05-24, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-05-24, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-05-25, the highest 'high' price occurred at 02:20:00 and repeated 1 times.
# On 2023-05-25, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-05-26, the highest 'high' price occurred at 04:25:00 and repeated 1 times.
# On 2023-05-26, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-05-29, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-05-29, the lowest 'low' price occurred at 02:45:00 and repeated 2 times.
# On 2023-05-30, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-05-30, the lowest 'low' price occurred at 04:50:00 and repeated 1 times.
# On 2023-05-31, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-05-31, the lowest 'low' price occurred at 04:30:00 and repeated 1 times.
# On 2023-06-01, the highest 'high' price occurred at 02:05:00 and repeated 1 times.
# On 2023-06-01, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-02, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-02, the lowest 'low' price occurred at 03:55:00 and repeated 1 times.
# On 2023-06-05, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2023-06-05, the lowest 'low' price occurred at 04:20:00 and repeated 1 times.
# On 2023-06-06, the highest 'high' price occurred at 04:10:00 and repeated 1 times.
# On 2023-06-06, the lowest 'low' price occurred at 02:35:00 and repeated 1 times.
# On 2023-06-07, the highest 'high' price occurred at 03:20:00 and repeated 2 times.
# On 2023-06-07, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-08, the highest 'high' price occurred at 04:35:00 and repeated 1 times.
# On 2023-06-08, the lowest 'low' price occurred at 03:05:00 and repeated 1 times.
# On 2023-06-09, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-06-09, the lowest 'low' price occurred at 03:20:00 and repeated 1 times.
# On 2023-06-12, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-12, the lowest 'low' price occurred at 02:25:00 and repeated 1 times.
# On 2023-06-13, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2023-06-13, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-06-14, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-06-14, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-06-15, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-06-15, the lowest 'low' price occurred at 04:10:00 and repeated 1 times.
# On 2023-06-16, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2023-06-16, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-06-19, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2023-06-19, the lowest 'low' price occurred at 04:00:00 and repeated 1 times.
# On 2023-06-20, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-20, the lowest 'low' price occurred at 04:15:00 and repeated 1 times.
# On 2023-06-21, the highest 'high' price occurred at 03:35:00 and repeated 1 times.
# On 2023-06-21, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-22, the highest 'high' price occurred at 02:10:00 and repeated 1 times.
# On 2023-06-22, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-23, the highest 'high' price occurred at 02:20:00 and repeated 1 times.
# On 2023-06-23, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-26, the highest 'high' price occurred at 04:40:00 and repeated 1 times.
# On 2023-06-26, the lowest 'low' price occurred at 03:30:00 and repeated 1 times.
# On 2023-06-27, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2023-06-27, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-06-28, the highest 'high' price occurred at 04:40:00 and repeated 1 times.
# On 2023-06-28, the lowest 'low' price occurred at 03:55:00 and repeated 1 times.
# On 2023-06-29, the highest 'high' price occurred at 02:20:00 and repeated 1 times.
# On 2023-06-29, the lowest 'low' price occurred at 03:55:00 and repeated 1 times.
# On 2023-06-30, the highest 'high' price occurred at 04:35:00 and repeated 1 times.
# On 2023-06-30, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-07-03, the highest 'high' price occurred at 03:55:00 and repeated 3 times.
# On 2023-07-03, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-07-04, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2023-07-04, the lowest 'low' price occurred at 04:25:00 and repeated 2 times.
# On 2023-07-05, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-07-05, the lowest 'low' price occurred at 04:10:00 and repeated 1 times.
# On 2023-07-06, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-07-06, the lowest 'low' price occurred at 03:30:00 and repeated 1 times.
# On 2023-07-07, the highest 'high' price occurred at 04:05:00 and repeated 1 times.
# On 2023-07-07, the lowest 'low' price occurred at 03:00:00 and repeated 2 times.
# On 2023-07-10, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-07-10, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-07-11, the highest 'high' price occurred at 04:15:00 and repeated 1 times.
# On 2023-07-11, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-12, the highest 'high' price occurred at 03:55:00 and repeated 1 times.
# On 2023-07-12, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-13, the highest 'high' price occurred at 02:30:00 and repeated 1 times.
# On 2023-07-13, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-14, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2023-07-14, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-17, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-17, the lowest 'low' price occurred at 04:45:00 and repeated 1 times.
# On 2023-07-18, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2023-07-18, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-07-19, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-19, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-07-20, the highest 'high' price occurred at 02:25:00 and repeated 1 times.
# On 2023-07-20, the lowest 'low' price occurred at 04:50:00 and repeated 2 times.
# On 2023-07-21, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-21, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-07-24, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-24, the lowest 'low' price occurred at 03:45:00 and repeated 1 times.
# On 2023-07-25, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-07-25, the lowest 'low' price occurred at 03:55:00 and repeated 1 times.
# On 2023-07-26, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-26, the lowest 'low' price occurred at 02:20:00 and repeated 2 times.
# On 2023-07-27, the highest 'high' price occurred at 03:50:00 and repeated 1 times.
# On 2023-07-27, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-07-28, the highest 'high' price occurred at 02:30:00 and repeated 1 times.
# On 2023-07-28, the lowest 'low' price occurred at 04:35:00 and repeated 1 times.
# On 2023-07-31, the highest 'high' price occurred at 02:20:00 and repeated 1 times.
# On 2023-07-31, the lowest 'low' price occurred at 04:00:00 and repeated 1 times.
# On 2023-08-01, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-01, the lowest 'low' price occurred at 03:20:00 and repeated 1 times.
# On 2023-08-02, the highest 'high' price occurred at 04:15:00 and repeated 1 times.
# On 2023-08-02, the lowest 'low' price occurred at 02:15:00 and repeated 1 times.
# On 2023-08-03, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-08-03, the lowest 'low' price occurred at 04:05:00 and repeated 1 times.
# On 2023-08-04, the highest 'high' price occurred at 02:10:00 and repeated 1 times.
# On 2023-08-04, the lowest 'low' price occurred at 04:05:00 and repeated 1 times.
# On 2023-08-07, the highest 'high' price occurred at 02:25:00 and repeated 1 times.
# On 2023-08-07, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-08, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-08, the lowest 'low' price occurred at 03:00:00 and repeated 1 times.
# On 2023-08-09, the highest 'high' price occurred at 04:05:00 and repeated 1 times.
# On 2023-08-09, the lowest 'low' price occurred at 03:25:00 and repeated 1 times.
# On 2023-08-10, the highest 'high' price occurred at 03:25:00 and repeated 1 times.
# On 2023-08-10, the lowest 'low' price occurred at 02:25:00 and repeated 2 times.
# On 2023-08-11, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-11, the lowest 'low' price occurred at 03:55:00 and repeated 1 times.
# On 2023-08-14, the highest 'high' price occurred at 04:45:00 and repeated 1 times.
# On 2023-08-14, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-15, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-15, the lowest 'low' price occurred at 04:40:00 and repeated 1 times.
# On 2023-08-16, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-16, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-08-17, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-08-17, the lowest 'low' price occurred at 02:50:00 and repeated 3 times.
# On 2023-08-18, the highest 'high' price occurred at 02:40:00 and repeated 1 times.
# On 2023-08-18, the lowest 'low' price occurred at 04:20:00 and repeated 1 times.
# On 2023-08-21, the highest 'high' price occurred at 04:05:00 and repeated 1 times.
# On 2023-08-21, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-22, the highest 'high' price occurred at 03:20:00 and repeated 1 times.
# On 2023-08-22, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-08-23, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-08-23, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-08-24, the highest 'high' price occurred at 04:35:00 and repeated 1 times.
# On 2023-08-24, the lowest 'low' price occurred at 02:05:00 and repeated 1 times.
# On 2023-08-25, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-08-25, the lowest 'low' price occurred at 03:40:00 and repeated 1 times.
# On 2023-08-28, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-28, the lowest 'low' price occurred at 04:05:00 and repeated 1 times.
# On 2023-08-29, the highest 'high' price occurred at 02:25:00 and repeated 1 times.
# On 2023-08-29, the lowest 'low' price occurred at 04:55:00 and repeated 2 times.
# On 2023-08-30, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-08-30, the lowest 'low' price occurred at 04:25:00 and repeated 1 times.
# On 2023-08-31, the highest 'high' price occurred at 03:15:00 and repeated 1 times.
# On 2023-08-31, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-09-01, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2023-09-01, the lowest 'low' price occurred at 03:20:00 and repeated 1 times.
# On 2023-09-04, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2023-09-04, the lowest 'low' price occurred at 03:15:00 and repeated 1 times.
# On 2023-09-05, the highest 'high' price occurred at 03:40:00 and repeated 1 times.
# On 2023-09-05, the lowest 'low' price occurred at 02:15:00 and repeated 1 times.
# On 2023-09-06, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-09-06, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-09-07, the highest 'high' price occurred at 02:40:00 and repeated 1 times.
# On 2023-09-07, the lowest 'low' price occurred at 04:20:00 and repeated 1 times.
# On 2023-09-08, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-09-08, the lowest 'low' price occurred at 03:45:00 and repeated 1 times.
# On 2023-09-11, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2023-09-11, the lowest 'low' price occurred at 02:30:00 and repeated 1 times.
# On 2023-09-12, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-09-12, the lowest 'low' price occurred at 04:50:00 and repeated 2 times.
# On 2023-09-13, the highest 'high' price occurred at 04:00:00 and repeated 1 times.
# On 2023-09-13, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-09-14, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2023-09-14, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-09-15, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-09-15, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-09-18, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-09-18, the lowest 'low' price occurred at 03:00:00 and repeated 1 times.
# On 2023-09-19, the highest 'high' price occurred at 02:00:00 and repeated 2 times.
# On 2023-09-19, the lowest 'low' price occurred at 04:25:00 and repeated 1 times.
# On 2023-09-20, the highest 'high' price occurred at 02:05:00 and repeated 1 times.
# On 2023-09-20, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-09-21, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-09-21, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-09-22, the highest 'high' price occurred at 04:20:00 and repeated 1 times.
# On 2023-09-22, the lowest 'low' price occurred at 02:00:00 and repeated 1 times.
# On 2023-09-25, the highest 'high' price occurred at 02:10:00 and repeated 2 times.
# On 2023-09-25, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-09-26, the highest 'high' price occurred at 03:55:00 and repeated 2 times.
# On 2023-09-26, the lowest 'low' price occurred at 02:10:00 and repeated 1 times.
# On 2023-09-27, the highest 'high' price occurred at 02:30:00 and repeated 1 times.
# On 2023-09-27, the lowest 'low' price occurred at 04:20:00 and repeated 1 times.
# On 2023-09-28, the highest 'high' price occurred at 04:55:00 and repeated 1 times.
# On 2023-09-28, the lowest 'low' price occurred at 04:30:00 and repeated 1 times.
# On 2023-09-29, the highest 'high' price occurred at 04:50:00 and repeated 1 times.
# On 2023-09-29, the lowest 'low' price occurred at 02:55:00 and repeated 2 times.
# On 2023-10-02, the highest 'high' price occurred at 03:05:00 and repeated 1 times.
# On 2023-10-02, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-10-03, the highest 'high' price occurred at 02:40:00 and repeated 1 times.
# On 2023-10-03, the lowest 'low' price occurred at 03:25:00 and repeated 1 times.
# On 2023-10-04, the highest 'high' price occurred at 04:30:00 and repeated 1 times.
# On 2023-10-04, the lowest 'low' price occurred at 02:50:00 and repeated 1 times.
# On 2023-10-05, the highest 'high' price occurred at 02:45:00 and repeated 2 times.
# On 2023-10-05, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-10-06, the highest 'high' price occurred at 02:25:00 and repeated 1 times.
# On 2023-10-06, the lowest 'low' price occurred at 04:55:00 and repeated 1 times.
# On 2023-10-09, the highest 'high' price occurred at 02:00:00 and repeated 1 times.
# On 2023-10-09, the lowest 'low' price occurred at 03:55:00 and repeated 1 times.
# On 2023-10-10, the highest 'high' price occurred at 02:25:00 and repeated 2 times.
# On 2023-10-10, the lowest 'low' price occurred at 04:15:00 and repeated 1 times.
# On 2023-10-11, the highest 'high' price occurred at 04:35:00 and repeated 1 times.
# On 2023-10-11, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-10-12, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-10-12, the lowest 'low' price occurred at 02:25:00 and repeated 1 times.
# On 2023-10-13, the highest 'high' price occurred at 04:10:00 and repeated 2 times.
# On 2023-10-13, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.
# On 2023-10-16, the highest 'high' price occurred at 05:00:00 and repeated 1 times.
# On 2023-10-16, the lowest 'low' price occurred at 02:20:00 and repeated 3 times.
# On 2023-10-17, the highest 'high' price occurred at 02:35:00 and repeated 1 times.
# On 2023-10-17, the lowest 'low' price occurred at 05:00:00 and repeated 1 times.

# %%
# Create a dictionary to store the count of events for each hour and time interval
hourly_event_counts = {}

# Iterate through the filtered data
for hour in range(0, 16):
    # Initialize the counts for each time interval
    counts = {
        'HH:00-HH:09': 0,
        'HH:10-HH:19': 0,
        'HH:20-HH:29': 0,
        'HH:30-HH:39': 0,
        'HH:40-HH:49': 0,
        'HH:50-HH:59': 0
    }

    # Filter the data for the current hour
    hour_data = filtered_df[filtered_df['datetime'].dt.hour == hour]

    # Iterate through each row in the filtered data
    for _, row in hour_data.iterrows():
        time_minute = row['datetime'].minute
        if 0 <= time_minute <= 9:
            counts['HH:00-HH:09'] += 1
        elif 10 <= time_minute <= 19:
            counts['HH:10-HH:19'] += 1
        elif 20 <= time_minute <= 29:
            counts['HH:20-HH:29'] += 1
        elif 30 <= time_minute <= 39:
            counts['HH:30-HH:39'] += 1
        elif 40 <= time_minute <= 49:
            counts['HH:30-HH:39'] += 1
        else:
            counts['HH:50-HH:59'] += 1

    # Store the counts in the dictionary
    hourly_event_counts[f'Hour {hour}'] = counts

# Print the results
for hour, counts in hourly_event_counts.items():
    print(f'For {hour}:')
    for interval, count in counts.items():
        print(f'{interval}: {count} times')
# Out:
# For Hour 0:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 1:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 2:
# HH:00-HH:09: 450 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 3:
# HH:00-HH:09: 452 times
# HH:10-HH:19: 452 times
# HH:20-HH:29: 452 times
# HH:30-HH:39: 904 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 452 times
# For Hour 4:
# HH:00-HH:09: 452 times
# HH:10-HH:19: 452 times
# HH:20-HH:29: 452 times
# HH:30-HH:39: 904 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 452 times
# For Hour 5:
# HH:00-HH:09: 227 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 6:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 7:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 8:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 9:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 10:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 11:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 12:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 13:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 14:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 15:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times

# %%
# Create a dictionary to store the count of events for each hour and time interval
hourly_event_counts = {}

# Iterate through the filtered data
for hour in range(2, 17):
    # Initialize the counts for each time interval
    counts = {
        'HH:00-HH:22': 0,
        'HH:23-HH:44': 0,
        'HH:45-HH:06': 0,
        'HH:07-HH:14': 0,
        'HH:15-HH:37': 0,
        'HH:38-HH:59': 0
    }

    # Filter the data for the current hour
    hour_data = filtered_df[filtered_df['datetime'].dt.hour == hour]

    # Iterate through each row in the filtered data
    for _, row in hour_data.iterrows():
        time_minute = row['datetime'].minute
        if 0 <= time_minute <= 22:
            counts['HH:00-HH:22'] += 1
        elif 23 <= time_minute <= 44:
            counts['HH:23-HH:44'] += 1
        elif 45 <= time_minute <= 6:
            counts['HH:45-HH:06'] += 1
        elif 7 <= time_minute <= 14:
            counts['HH:07-HH:14'] += 1
        elif 15 <= time_minute <= 37:
            counts['HH:15-HH:37'] += 1
        else:
            counts['HH:38-HH:59'] += 1

    # Store the counts in the dictionary
    hourly_event_counts[f'Hour {hour}'] = counts

# Print the results
for hour, counts in hourly_event_counts.items():
    print(f'For {hour}:')
    for interval, count in counts.items():
        print(f'{interval}: {count} times')
# Out:
# For Hour 2:
# HH:00-HH:22: 1125 times
# HH:23-HH:44: 900 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 675 times
# For Hour 3:
# HH:00-HH:22: 1130 times
# HH:23-HH:44: 904 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 678 times
# For Hour 4:
# HH:00-HH:22: 1130 times
# HH:23-HH:44: 904 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 678 times
# For Hour 5:
# HH:00-HH:22: 227 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 6:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 7:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 8:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 9:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 10:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 11:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 12:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 13:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 14:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 15:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times
# For Hour 16:
# HH:00-HH:22: 0 times
# HH:23-HH:44: 0 times
# HH:45-HH:06: 0 times
# HH:07-HH:14: 0 times
# HH:15-HH:37: 0 times
# HH:38-HH:59: 0 times

# %%
# Create a dictionary to store the count of events for each hour and time interval
hourly_event_counts = {}

# Iterate through the filtered data
for hour in range(0, 16):
    # Initialize the counts for each time interval
    counts = {
        'HH:00-HH:09': 0,
        'HH:10-HH:19': 0,
        'HH:20-HH:29': 0,
        'HH:30-HH:39': 0,
        'HH:40-HH:49': 0,
        'HH:50-HH:59': 0
    }

    # Filter the data for the current hour
    hour_data = filtered_df[filtered_df['datetime'].dt.hour == hour]

    # Iterate through each row in the filtered data
    for _, row in hour_data.iterrows():
        time_minute = row['datetime'].minute
        if 0 <= time_minute <= 9:
            counts['HH:00-HH:09'] += 1
        elif 10 <= time_minute <= 19:
            counts['HH:10-HH:19'] += 1
        elif 20 <= time_minute <= 29:
            counts['HH:20-HH:29'] += 1
        elif 30 <= time_minute <= 39:
            counts['HH:30-HH:39'] += 1
        elif 40 <= time_minute <= 49:
            counts['HH:30-HH:39'] += 1
        else:
            counts['HH:50-HH:59'] += 1

    # Store the counts in the dictionary
    hourly_event_counts[f'Hour {hour}'] = counts

# Print the results
for hour, counts in hourly_event_counts.items():
    print(f'For {hour}:')
    for interval, count in counts.items():
        print(f'{interval}: {count} times')
# Out:
# For Hour 0:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 1:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 2:
# HH:00-HH:09: 450 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 3:
# HH:00-HH:09: 450 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 4:
# HH:00-HH:09: 450 times
# HH:10-HH:19: 450 times
# HH:20-HH:29: 450 times
# HH:30-HH:39: 900 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 450 times
# For Hour 5:
# HH:00-HH:09: 45 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 6:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 7:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 8:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 9:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 10:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 11:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 12:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 13:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 14:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times
# For Hour 15:
# HH:00-HH:09: 0 times
# HH:10-HH:19: 0 times
# HH:20-HH:29: 0 times
# HH:30-HH:39: 0 times
# HH:40-HH:49: 0 times
# HH:50-HH:59: 0 times

# %%
LDOAM  = time(timeframe.period, '0142-0200', 'UTC-4') and showLDOAM
LDOAM2  = time(timeframe.period, '0212-0230', 'UTC-4') and showLDOAM
LDOAM3  = time(timeframe.period, '0242-0300', 'UTC-4') and showLDOAM
LDOAM4  = time(timeframe.period, '0312-0330', 'UTC-4') and showLDOAM
LDOAM5  = time(timeframe.period, '0342-0400', 'UTC-4') and showLDOAM
LDOAM6  = time(timeframe.period, '0412-0430', 'UTC-4') and showLDOAM
LDOAM7  = time(timeframe.period, '0442-0500', 'UTC-4') and showLDOAM
LDOAM8  = time(timeframe.period, '0512-0530', 'UTC-4') and showLDOAM
LDOAM9  = time(timeframe.period, '0542-0600', 'UTC-4') and showLDOAM

NYLAM  = time(timeframe.period, '0612-0630', 'UTC-4') and showNYLAM
NYLAM2  = time(timeframe.period, '0642-0700', 'UTC-4') and showNYLAM
NYLAM3  = time(timeframe.period, '0712-0730', 'UTC-4') and showNYLAM
NYLAM4  = time(timeframe.period, '0742-0800', 'UTC-4') and showNYLAM
NYLAM5  = time(timeframe.period, '0812-0830', 'UTC-4') and showNYLAM
NYLAM6  = time(timeframe.period, '0842-0900', 'UTC-4') and showNYLAM
NYLAM7  = time(timeframe.period, '0912-0930', 'UTC-4') and showNYLAM
NYLAM8  = time(timeframe.period, '0942-1000', 'UTC-4') and showNYLAM
NYLAM9  = time(timeframe.period, '1012-1030', 'UTC-4') and showNYLAM
NYLAM10  = time(timeframe.period, '1042-1100', 'UTC-4') and showNYLAM
NYLAM11  = time(timeframe.period, '1112-1130', 'UTC-4') and showNYLAM
NYLAM12  = time(timeframe.period, '1142-1200', 'UTC-4') and showNYLAM

# %%
# Create a dictionary to store the count of events for each hour and time interval
hourly_event_counts = {}

# Iterate through the filtered data
for hour in range(0, 19):
    # Initialize the counts for each time interval
    counts = {
        'HH:00-HH:21': 0,
        'HH:22-HH:41': 0,
        'HH:42-HH:59': 0,
    }

    # Filter the data for the current hour
    hour_data = filtered_df[filtered_df['datetime'].dt.hour == hour]

    # Iterate through each row in the filtered data
    for _, row in hour_data.iterrows():
        time_minute = row['datetime'].minute
        if 0 <= time_minute <= 21:
            counts['HH:00-HH:21'] += 1
        elif 22 <= time_minute <= 41:
            counts['HH:22-HH:41'] += 1
        elif 42 <= time_minute <= 59:
            counts['HH:42-HH:59'] += 1
        else:
            counts['HH:00-HH:01'] += 1

    # Store the counts in the dictionary
    hourly_event_counts[f'Hour {hour}'] = counts

# Print the results
for hour, counts in hourly_event_counts.items():
    print(f'For {hour}:')
    for interval, count in counts.items():
        print(f'{interval}: {count} times')
# Out:
# For Hour 0:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 1:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 2:
# HH:00-HH:21: 990 times
# HH:22-HH:41: 900 times
# HH:42-HH:59: 810 times
# For Hour 3:
# HH:00-HH:21: 990 times
# HH:22-HH:41: 900 times
# HH:42-HH:59: 810 times
# For Hour 4:
# HH:00-HH:21: 990 times
# HH:22-HH:41: 900 times
# HH:42-HH:59: 810 times
# For Hour 5:
# HH:00-HH:21: 45 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 6:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 7:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 8:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 9:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 10:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 11:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 12:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 13:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 14:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 15:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 16:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 17:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times
# For Hour 18:
# HH:00-HH:21: 0 times
# HH:22-HH:41: 0 times
# HH:42-HH:59: 0 times

# %%
# Create a dictionary to store the count of events for each hour and time interval
hourly_event_counts = {}

# Iterate through the filtered data
for hour in range(0, 16):
    # Initialize the counts for each time interval
    counts = {
        'HH:01-HH:14': 0,
        'HH:15-HH:29': 0,
        'HH:30-HH:44': 0,
        'HH:45-HH:00': 0,
    }

    # Filter the data for the current hour
    hour_data = filtered_df[filtered_df['datetime'].dt.hour == hour]

    # Iterate through each row in the filtered data
    for _, row in hour_data.iterrows():
        time_minute = row['datetime'].minute
        if 1 <= time_minute <= 14:
            counts['HH:01-HH:14'] += 1
        elif 15 <= time_minute <= 29:
            counts['HH:15-HH:29'] += 1
        elif 30 <= time_minute <= 44:
            counts['HH:30-HH:44'] += 1
        else:
            counts['HH:45-HH:00'] += 1

    # Store the counts in the dictionary
    hourly_event_counts[f'Hour {hour}'] = counts

# Print the results
for hour, counts in hourly_event_counts.items():
    print(f'For {hour}:')
    for interval, count in counts.items():
        print(f'{interval}: {count} times')
# Out:
# For Hour 0:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 0 times
# HH:30-HH:44: 0 times
# HH:45-HH:00: 0 times
# For Hour 1:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 0 times
# HH:30-HH:44: 0 times
# HH:45-HH:00: 0 times
# For Hour 2:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 0 times
# HH:30-HH:44: 0 times
# HH:45-HH:00: 0 times
# For Hour 3:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 0 times
# HH:30-HH:44: 0 times
# HH:45-HH:00: 0 times
# For Hour 4:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 0 times
# HH:30-HH:44: 0 times
# HH:45-HH:00: 0 times
# For Hour 5:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 0 times
# HH:30-HH:44: 0 times
# HH:45-HH:00: 0 times
# For Hour 6:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 676 times
# HH:30-HH:44: 676 times
# HH:45-HH:00: 1352 times
# For Hour 7:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 677 times
# HH:30-HH:44: 677 times
# HH:45-HH:00: 1354 times
# For Hour 8:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 677 times
# HH:30-HH:44: 677 times
# HH:45-HH:00: 1354 times
# For Hour 9:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 678 times
# HH:30-HH:44: 678 times
# HH:45-HH:00: 1356 times
# For Hour 10:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 678 times
# HH:30-HH:44: 678 times
# HH:45-HH:00: 1356 times
# For Hour 11:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 679 times
# HH:30-HH:44: 679 times
# HH:45-HH:00: 1358 times
# For Hour 12:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 679 times
# HH:30-HH:44: 679 times
# HH:45-HH:00: 1358 times
# For Hour 13:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 679 times
# HH:30-HH:44: 679 times
# HH:45-HH:00: 1358 times
# For Hour 14:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 679 times
# HH:30-HH:44: 679 times
# HH:45-HH:00: 1358 times
# For Hour 15:
# HH:01-HH:14: 0 times
# HH:15-HH:29: 679 times
# HH:30-HH:44: 679 times
# HH:45-HH:00: 1357 times
